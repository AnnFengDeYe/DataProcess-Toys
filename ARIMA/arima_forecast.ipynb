    '重庆': [102.75, 100.41, 101.57, 106.55, 114.16, 121.60, 124.25, 125.97, 133.25, 137.74, 135.04, 127.64],
    '四川': [81.00, 79.10, 76.08, 79.77, 84.60, 93.11, 102.90, 113.31, 119.91, 122.47, 123.51, 123.87],
    '贵州': [89.62, 86.83, 86.88, 87.79, 88.32, 90.12, 93.71, 99.87, 106.60, 112.67, 119.83, 130.30],
    '云南': [80.81, 77.35, 75.27, 77.48, 78.58, 79.47, 82.45, 86.30, 91.38, 96.33, 101.33, 105.39],
    '西藏': [74.32, 70.98, 69.00, 69.93, 69.96, 76.07, 82.03, 86.08, 93.34, 96.17, 98.87, 105.35],
    '陕西': [96.26, 88.81, 86.26, 86.47, 88.89, 90.21, 90.20, 93.59, 98.10, 103.18, 106.50, 111.76],
    '甘肃': [95.20, 92.64, 85.75, 85.41, 85.01, 86.11, 87.14, 90.39, 91.84, 89.78, 89.34, 90.00],
    '青海': [69.02, 64.55, 65.40, 68.36, 70.75, 71.31, 73.23, 82.55, 86.22, 88.09, 88.71, 92.20],
    '宁夏': [99.90, 98.09, 97.06, 97.05, 97.08, 97.99, 99.57, 103.29, 105.57, 103.56, 103.08, 103.77],
    '新疆': [97.27, 92.13, 89.93, 91.16, 93.39, 94.14, 95.66, 97.02, 100.66, 104.38, 108.85, 112.66],
    '大连市': [127.53, 127.86, 125.98, 122.01, 123.20, 123.97, 130.33, 133.51, 141.03, 141.90, 138.07, 134.99],
    '宁波市': [132.53, 128.27, 128.12, 130.14, 139.07, 145.67, 149.69, 147.43, 153.23, 158.37, 161.93, 163.06],
    '厦门市': [112.40, 112.22, 114.87, 219.25, 227.30, 243.44, 254.68, 253.30, 250.15, 246.08, 237.01, 230.31],
    # 第4批 (本次新增)
    '青岛市': [111.81, 110.71, 113.06, 113.91, 114.40, 115.71, 118.40, 120.25, 121.36, 124.85, 130.45, 138.36],
    '深圳市': [597.57, 603.29, 578.65, 534.73, 482.72, 460.55, 474.07, 490.73, 484.91, 436.45, 402.13, 382.65]
}
# --- 结束更新 data 字典 ---

df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
# 将索引转换为 PeriodIndex，更适合年度数据
df.index = df.index.to_period('A')

# 2. 定义预测参数
# locations 列表会自动更新，因为它是从 data 字典动态生成的
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021 # 预测 14 年 (2022 到 2035)

# 3. 循环为每个地区/城市进行 ARIMA 预测
forecast_results = {}
fitted_models = {}

print(f"共 {len(locations)} 个地区/城市需要处理。")
print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n")

for i, loc in enumerate(locations):
    print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---")
    series = df[loc]

    try:
        # 使用 auto_arima 自动寻找最佳模型参数
        auto_model = pm.auto_arima(series,
                                   start_p=0, start_q=0,
                                   max_p=3, max_q=3, # 限制模型复杂度
                                   m=1,              # 年度数据，非季节性
                                   d=None,           # 让 auto_arima 自动确定 d
                                   test='adf',       # 使用 ADF 检验确定 d
                                   seasonal=False,   # 明确指定非季节性
                                   stepwise=True,    # 使用 stepwise 算法加速搜索
                                   suppress_warnings=True, 
                                   error_action='ignore', # 忽略不合适的模型
                                   trace=False)       # 不打印搜索过程中的每一步

        if auto_model is None or not hasattr(auto_model, 'order'):
             raise ValueError("auto_arima未能找到合适的模型。")

        print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}")

        # 打印模型详细参数
        print("模型详细参数:")
        print(auto_model.summary())
        print("-" * 60) # 添加分隔线

        fitted_models[loc] = auto_model # 保存拟合好的模型

        # 进行预测
        forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)

        # 将预测结果添加到字典
        forecast_results[loc] = forecast

    except Exception as e:
        print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}")
        print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。")
        # 如果模型失败，用 NaN 填充预测值
        forecast_results[loc] = [np.nan] * forecast_horizon
        fitted_models[loc] = None
    finally:
        print("\n") # 每个地区处理完后加一个空行

# 4. 整理并展示预测结果
forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(forecast_df_formatted)
pd.reset_option('display.max_columns')
pd.reset_option('display.width')

# 5. 可选：绘制历史数据和预测结果
plot_results = False # 设置为 False 则不绘图

if plot_results:
    print("\n--- 正在绘制结果图表 ---")
    n_locations = len(locations)
    cols_per_row = 3
    n_rows = (n_locations + cols_per_row - 1) // cols_per_row
    fig_width = 15
    fig_height_per_row = 4
    fig_height = n_rows * fig_height_per_row

    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=(fig_width, fig_height), sharex=True, squeeze=False)
    fig.suptitle('各地区/城市比例历史数据与 ARIMA 预测 (2010-2035)', fontsize=16, y=0.99)

    try:
        plt.rcParams['font.sans-serif'] = ['SimHei']
        plt.rcParams['axes.unicode_minus'] = False
    except Exception as font_error:
        print(f"\n注意: 设置中文字体失败: {font_error}")
        print("图表标题和标签可能显示乱码。")

    axes_flat = axes.flatten()

    for i, loc in enumerate(locations):
        ax = axes_flat[i]
        # 绘制历史数据
        if loc in df.columns:
             df[loc].plot(ax=ax, label='历史数据', marker='o', linestyle='-')

        # 绘制预测数据
        if loc in forecast_df.columns and forecast_df[loc].notna().any():
            forecast_df[loc].plot(ax=ax, label='ARIMA 预测', linestyle='--', marker='x')

            # 绘制置信区间
            if fitted_models.get(loc) is not None:
                try:
                    _, conf_int_plot = fitted_models[loc].predict(n_periods=forecast_horizon, return_conf_int=True)
                    conf_int_df = pd.DataFrame(conf_int_plot, index=forecast_index, columns=['lower', 'upper'])
                    # 对于数值范围特别大的序列(如深圳)，置信区间可能非常宽，甚至出现负值
                    # 可以考虑对置信区间下限进行限制，例如不小于0
                    conf_int_df['lower'] = conf_int_df['lower'].clip(lower=0)

                    ax.fill_between(conf_int_df.index.to_timestamp(),
                                    conf_int_df['lower'],
                                    conf_int_df['upper'],
                                    color='gray', alpha=0.2, label='95% 置信区间 (≥0)')
                except Exception as plot_ci_error:
                     print(f"绘制 {loc} 的置信区间时出错: {plot_ci_error}")

        ax.set_title(loc)
        ax.set_ylabel('比例 (%)')
        ax.legend(fontsize='small')
        ax.grid(True, linestyle=':', alpha=0.6)
        # 对于数值范围差异巨大的序列（如深圳 vs 其他），Y轴自动缩放可能使其他图难以辨认
        # 可以考虑为特定序列设置不同的Y轴，但这会使比较困难
        # 或者接受Y轴自动缩放，关注每个图的自身趋势
        # ax.set_ylim(bottom=0) # 强制Y轴从0开始

    # 隐藏多余的子图
    for j in range(i + 1, len(axes_flat)):
        axes_flat[j].set_visible(False)

    # 调整X轴标签
    for row in range(n_rows):
        for col in range(cols_per_row):
            ax = axes[row, col]
            if ax.is_visible():
                if row == n_rows - 1:
                    ax.set_xlabel('年份')
                else:
                    ax.tick_params(labelbottom=False)

    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()
# Out:
# 共 36 个地区/城市需要处理。
# 开始为每个地区/城市拟合 ARIMA 模型并预测...
#
# --- 正在处理: 北京 (1/36) ---
# 为 '北京' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -33.683
# Date:                Wed, 26 Mar 2025   AIC                             69.366
# Time:                        12:07:58   BIC                             69.669
# Sample:                    12-31-2010   HQIC                            69.034
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        49.3411     26.923      1.833      0.067      -3.427     102.109
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.73
# Prob(Q):                              0.70   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.52   Skew:                            -0.35
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 天津 (2/36) ---
# 为 '天津' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -26.546
# Date:                Wed, 26 Mar 2025   AIC                             55.091
# Time:                        12:07:58   BIC                             55.394
# Sample:                    12-31-2010   HQIC                            54.760
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        11.8373      6.931      1.708      0.088      -1.746      25.421
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.51   Jarque-Bera (JB):                 0.35
# Prob(Q):                              0.47   Prob(JB):                         0.84
# Heteroskedasticity (H):               0.46   Skew:                             0.15
# Prob(H) (two-sided):                  0.54   Kurtosis:                         2.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河北 (3/36) ---
# 为 '河北' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.479
# Date:                Wed, 26 Mar 2025   AIC                             62.957
# Time:                        12:07:58   BIC                             63.260
# Sample:                    12-31-2010   HQIC                            62.625
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.9936      9.137      2.845      0.004       8.086      43.901
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.16   Jarque-Bera (JB):                 3.67
# Prob(Q):                              0.28   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.17   Skew:                             1.36
# Prob(H) (two-sided):                  0.17   Kurtosis:                         4.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山西 (4/36) ---
# 为 '山西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.831
# Date:                Wed, 26 Mar 2025   AIC                             59.662
# Time:                        12:07:58   BIC                             59.965
# Sample:                    12-31-2010   HQIC                            59.330
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        18.6965      6.067      3.082      0.002       6.806      30.587
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.20   Jarque-Bera (JB):                 2.86
# Prob(Q):                              0.14   Prob(JB):                         0.24
# Heteroskedasticity (H):               0.05   Skew:                             1.25
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 内蒙古 (5/36) ---
# 为 '内蒙古' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.952
# Date:                Wed, 26 Mar 2025   AIC                             49.904
# Time:                        12:07:58   BIC                             50.207
# Sample:                    12-31-2010   HQIC                            49.572
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         7.0466      3.725      1.892      0.059      -0.254      14.347
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.14
# Prob(Q):                              0.98   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.94   Skew:                             0.04
# Prob(H) (two-sided):                  0.96   Kurtosis:                         2.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 辽宁 (6/36) ---
# 为 '辽宁' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -31.339
# Date:                Wed, 26 Mar 2025   AIC                             64.678
# Time:                        12:07:58   BIC                             64.980
# Sample:                    12-31-2010   HQIC                            64.346
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        30.8733     17.440      1.770      0.077      -3.309      65.056
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.29   Jarque-Bera (JB):                 0.24
# Prob(Q):                              0.26   Prob(JB):                         0.89
# Heteroskedasticity (H):               0.27   Skew:                             0.12
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 吉林 (7/36) ---
# 为 '吉林' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.307
# Date:                Wed, 26 Mar 2025   AIC                             62.614
# Time:                        12:07:58   BIC                             62.917
# Sample:                    12-31-2010   HQIC                            62.282
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.1164     10.450      2.403      0.016       4.635      45.598
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.59   Jarque-Bera (JB):                 3.30
# Prob(Q):                              0.44   Prob(JB):                         0.19
# Heteroskedasticity (H):               2.18   Skew:                            -1.35
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 黑龙江 (8/36) ---
# 为 '黑龙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -36.770
# Date:                Wed, 26 Mar 2025   AIC                             75.539
# Time:                        12:07:58   BIC                             75.842
# Sample:                    12-31-2010   HQIC                            75.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        91.4745     33.203      2.755      0.006      26.397     156.552
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.75   Jarque-Bera (JB):                 1.08
# Prob(Q):                              0.19   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.04   Skew:                             0.55
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 上海 (9/36) ---
# 为 '上海' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.030
# Date:                Wed, 26 Mar 2025   AIC                             72.059
# Time:                        12:07:58   BIC                             72.362
# Sample:                    12-31-2010   HQIC                            71.727
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        64.5907     47.316      1.365      0.172     -28.148     157.329
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.53   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.80   Skew:                             0.01
# Prob(H) (two-sided):                  0.86   Kurtosis:                         1.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江苏 (10/36) ---
# 为 '江苏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -21.589
# Date:                Wed, 26 Mar 2025   AIC                             45.178
# Time:                        12:07:59   BIC                             45.481
# Sample:                    12-31-2010   HQIC                            44.846
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         4.3928      1.479      2.970      0.003       1.494       7.291
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.14   Jarque-Bera (JB):                 2.18
# Prob(Q):                              0.28   Prob(JB):                         0.34
# Heteroskedasticity (H):               0.26   Skew:                             1.07
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 浙江 (11/36) ---
# 为 '浙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.813
# Date:                Wed, 26 Mar 2025   AIC                             49.627
# Time:                        12:07:59   BIC                             49.929
# Sample:                    12-31-2010   HQIC                            49.295
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         6.8537      4.466      1.535      0.125      -1.899      15.606
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.75   Prob(JB):                         0.79
# Heteroskedasticity (H):               1.10   Skew:                            -0.09
# Prob(H) (two-sided):                  0.94   Kurtosis:                         1.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 安徽 (12/36) ---
# 为 '安徽' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -26.140
# Date:                Wed, 26 Mar 2025   AIC                             56.281
# Time:                        12:07:59   BIC                             56.886
# Sample:                    12-31-2010   HQIC                            55.617
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7863      0.198      3.979      0.000       0.399       1.174
# sigma2         9.9119      8.053      1.231      0.218      -5.873      25.696
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.44   Jarque-Bera (JB):                 0.86
# Prob(Q):                              0.23   Prob(JB):                         0.65
# Heteroskedasticity (H):               0.42   Skew:                             0.65
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 福建 (13/36) ---
# 为 '福建' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -31.026
# Date:                Wed, 26 Mar 2025   AIC                             70.052
# Time:                        12:07:59   BIC                             71.992
# Sample:                    12-31-2010   HQIC                            69.334
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     15.0542     26.445      0.569      0.569     -36.777      66.886
# ar.L1          1.4890      0.482      3.088      0.002       0.544       2.434
# ar.L2         -0.6392      0.605     -1.057      0.291      -1.825       0.546
# sigma2         8.1685      3.930      2.078      0.038       0.465      15.872
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.10
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                            -1.87
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江西 (14/36) ---
# 为 '江西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.263
# Date:                Wed, 26 Mar 2025   AIC                             62.526
# Time:                        12:07:59   BIC                             62.829
# Sample:                    12-31-2010   HQIC                            62.194
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        24.8965     12.727      1.956      0.050      -0.048      49.841
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.16
# Prob(Q):                              0.76   Prob(JB):                         0.92
# Heteroskedasticity (H):               0.72   Skew:                             0.24
# Prob(H) (two-sided):                  0.80   Kurtosis:                         2.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山东 (15/36) ---
# 为 '山东' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.029
# Date:                Wed, 26 Mar 2025   AIC                             54.058
# Time:                        12:07:59   BIC                             54.663
# Sample:                    12-31-2010   HQIC                            53.394
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.4900      0.963      1.546      0.122      -0.398       3.378
# sigma2         8.7400      3.980      2.196      0.028       0.940      16.540
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.20
# Prob(Q):                              0.89   Prob(JB):                         0.90
# Heteroskedasticity (H):               1.05   Skew:                            -0.35
# Prob(H) (two-sided):                  0.97   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河南 (16/36) ---
# 为 '河南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.484
# Date:                Wed, 26 Mar 2025   AIC                             72.969
# Time:                        12:07:59   BIC                             73.271
# Sample:                    12-31-2010   HQIC                            72.637
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        70.7411     21.516      3.288      0.001      28.571     112.911
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.83   Jarque-Bera (JB):                 3.60
# Prob(Q):                              0.09   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.04   Skew:                             1.12
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖北 (17/36) ---
# 为 '湖北' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -36.091
# Date:                Wed, 26 Mar 2025   AIC                             80.182
# Time:                        12:07:59   BIC                             82.122
# Sample:                    12-31-2010   HQIC                            79.464
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     19.1772      8.223      2.332      0.020       3.061      35.294
# ar.L1          1.6825      0.119     14.182      0.000       1.450       1.915
# ar.L2         -0.8738      0.133     -6.573      0.000      -1.134      -0.613
# sigma2        16.4486      9.773      1.683      0.092      -2.706      35.603
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.31   Prob(JB):                         0.85
# Heteroskedasticity (H):               0.17   Skew:                             0.36
# Prob(H) (two-sided):                  0.11   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖南 (18/36) ---
# 为 '湖南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -22.425
# Date:                Wed, 26 Mar 2025   AIC                             46.851
# Time:                        12:07:59   BIC                             47.154
# Sample:                    12-31-2010   HQIC                            46.519
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         5.1925      2.833      1.833      0.067      -0.361      10.746
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.68   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.27   Skew:                             0.53
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广东 (19/36) ---
# 为 '广东' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -15.903
# Date:                Wed, 26 Mar 2025   AIC                             39.806
# Time:                        12:07:59   BIC                             41.016
# Sample:                    12-31-2010   HQIC                            38.478
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7090      1.008      0.704      0.482      -1.266       2.684
# ar.L1          1.1133      0.323      3.443      0.001       0.479       1.747
# ar.L2         -0.8347      0.129     -6.446      0.000      -1.088      -0.581
# sigma2         1.0600      1.107      0.958      0.338      -1.110       3.229
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 2.94
# Prob(Q):                              0.81   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.43   Skew:                            -1.33
# Prob(H) (two-sided):                  0.78   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广西 (20/36) ---
# 为 '广西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -19.483
# Date:                Wed, 26 Mar 2025   AIC                             40.967
# Time:                        12:07:59   BIC                             41.270
# Sample:                    12-31-2010   HQIC                            40.635
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         2.8830      2.328      1.239      0.216      -1.679       7.445
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.77   Prob(JB):                         0.65
# Heteroskedasticity (H):               1.92   Skew:                            -0.05
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 海南 (21/36) ---
# 为 '海南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -20.622
# Date:                Wed, 26 Mar 2025   AIC                             43.244
# Time:                        12:07:59   BIC                             43.547
# Sample:                    12-31-2010   HQIC                            42.912
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         3.6203      2.176      1.664      0.096      -0.645       7.886
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.08   Jarque-Bera (JB):                 1.10
# Prob(Q):                              0.30   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.15   Skew:                             0.26
# Prob(H) (two-sided):                  0.15   Kurtosis:                         1.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 重庆 (22/36) ---
# 为 '重庆' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.358
# Date:                Wed, 26 Mar 2025   AIC                             58.716
# Time:                        12:08:00   BIC                             59.018
# Sample:                    12-31-2010   HQIC                            58.384
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        17.0080     12.274      1.386      0.166      -7.048      41.064
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.20   Prob(JB):                         0.69
# Heteroskedasticity (H):               2.42   Skew:                            -0.09
# Prob(H) (two-sided):                  0.49   Kurtosis:                         1.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 四川 (23/36) ---
# 为 '四川' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.537
# Date:                Wed, 26 Mar 2025   AIC                             53.075
# Time:                        12:08:00   BIC                             53.377
# Sample:                    12-31-2010   HQIC                            52.743
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.6751      4.459      2.170      0.030       0.937      18.414
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.22   Jarque-Bera (JB):                 0.53
# Prob(Q):                              0.27   Prob(JB):                         0.77
# Heteroskedasticity (H):               0.40   Skew:                             0.55
# Prob(H) (two-sided):                  0.47   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 贵州 (24/36) ---
# 为 '贵州' 找到的最佳 ARIMA 模型阶数: (1, 1, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 -21.403
# Date:                Wed, 26 Mar 2025   AIC                             48.805
# Time:                        12:08:00   BIC                             49.999
# Sample:                    12-31-2010   HQIC                            48.053
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9515      0.106      8.971      0.000       0.744       1.159
# ma.L1          0.8065      0.708      1.139      0.255      -0.581       2.194
# sigma2         1.8979      1.202      1.579      0.114      -0.457       4.253
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.77   Jarque-Bera (JB):                 0.82
# Prob(Q):                              0.38   Prob(JB):                         0.66
# Heteroskedasticity (H):               1.81   Skew:                             0.20
# Prob(H) (two-sided):                  0.58   Kurtosis:                         1.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 云南 (25/36) ---
# 为 '云南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.455
# Date:                Wed, 26 Mar 2025   AIC                             40.910
# Time:                        12:08:00   BIC                             41.516
# Sample:                    12-31-2010   HQIC                            40.247
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7520      0.617      1.218      0.223      -0.458       1.962
# sigma2         2.3471      1.246      1.884      0.060      -0.095       4.789
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 1.51
# Prob(Q):                              0.72   Prob(JB):                         0.47
# Heteroskedasticity (H):               0.25   Skew:                             0.94
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 西藏 (26/36) ---
# 为 '西藏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.498
# Date:                Wed, 26 Mar 2025   AIC                             52.996
# Time:                        12:08:00   BIC                             53.299
# Sample:                    12-31-2010   HQIC                            52.664
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.5997      5.256      1.826      0.068      -0.702      19.902
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.21
# Prob(Q):                              0.20   Prob(JB):                         0.90
# Heteroskedasticity (H):               3.05   Skew:                            -0.08
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 陕西 (27/36) ---
# 为 '陕西' 找到的最佳 ARIMA 模型阶数: (1, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                 -25.998
# Date:                Wed, 26 Mar 2025   AIC                             55.995
# Time:                        12:08:00   BIC                             56.791
# Sample:                    12-31-2010   HQIC                            55.494
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8771      0.139      6.321      0.000       0.605       1.149
# ...
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3119      0.451      2.907      0.004       0.427       2.196
# ar.L2         -0.5021      0.385     -1.304      0.192      -1.257       0.253
# sigma2         2.3163      1.669      1.388      0.165      -0.955       5.588
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.14   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.81   Skew:                            -0.15
# Prob(H) (two-sided):                  0.84   Kurtosis:                         1.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 大连市 (32/36) ---
# 为 '大连市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -34.462
# Date:                Wed, 26 Mar 2025   AIC                             76.925
# Time:                        12:08:00   BIC                             78.864
# Sample:                    12-31-2010   HQIC                            76.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9988      0.024     41.692      0.000       0.952       1.046
# ma.L1          0.5881      0.642      0.916      0.359      -0.670       1.846
# ma.L2          0.5414      0.554      0.978      0.328      -0.544       1.627
# sigma2         9.1032      7.754      1.174      0.240      -6.094      24.300
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.54
# Prob(Q):                              0.84   Prob(JB):                         0.76
# Heteroskedasticity (H):               2.79   Skew:                            -0.16
# Prob(H) (two-sided):                  0.34   Kurtosis:                         2.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 宁波市 (33/36) ---
# 为 '宁波市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -33.333
# Date:                Wed, 26 Mar 2025   AIC                             76.665
# Time:                        12:08:01   BIC                             79.090
# Sample:                    12-31-2010   HQIC                            75.768
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     26.4557     96.668      0.274      0.784    -163.011     215.922
# ar.L1          0.8210      0.666      1.232      0.218      -0.485       2.127
# ma.L1          0.8449      1.355      0.624      0.533      -1.811       3.501
# ma.L2          0.5714      0.874      0.654      0.513      -1.142       2.285
# sigma2        11.1114      5.137      2.163      0.031       1.042      21.180
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.96   Prob(JB):                         0.71
# Heteroskedasticity (H):               2.21   Skew:                             0.57
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 厦门市 (34/36) ---
# 为 '厦门市' 找到的最佳 ARIMA 模型阶数: (1, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -58.960
# Date:                Wed, 26 Mar 2025   AIC                            123.919
# Time:                        12:08:01   BIC                            125.374
# Sample:                    12-31-2010   HQIC                           123.380
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     27.9320    103.856      0.269      0.788    -175.621     231.485
# ar.L1          0.8531      0.598      1.427      0.154      -0.319       2.025
# sigma2       972.8598    843.183      1.154      0.249    -679.748    2625.468
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 8.70
# Prob(Q):                              0.86   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.01   Skew:                             1.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 青岛市 (35/36) ---
# 为 '青岛市' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.859
# Date:                Wed, 26 Mar 2025   AIC                             41.719
# Time:                        12:08:01   BIC                             42.324
# Sample:                    12-31-2010   HQIC                            41.055
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9010      0.505      1.785      0.074      -0.088       1.890
# sigma2         2.5447      2.034      1.251      0.211      -1.442       6.532
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.79
# Prob(Q):                              0.99   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.41   Skew:                            -0.03
# Prob(H) (two-sided):                  0.48   Kurtosis:                         1.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 深圳市 (36/36) ---
# 为 '深圳市' 找到的最佳 ARIMA 模型阶数: (3, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(3, 1, 0)   Log Likelihood                 -41.004
# Date:                Wed, 26 Mar 2025   AIC                             92.008
# Time:                        12:08:01   BIC                             93.998
# Sample:                    12-31-2010   HQIC                            90.754
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# interc
    '重庆': [102.75, 100.41, 101.57, 106.55, 114.16, 121.60, 124.25, 125.97, 133.25, 137.74, 135.04, 127.64],
    '四川': [81.00, 79.10, 76.08, 79.77, 84.60, 93.11, 102.90, 113.31, 119.91, 122.47, 123.51, 123.87],
    '贵州': [89.62, 86.83, 86.88, 87.79, 88.32, 90.12, 93.71, 99.87, 106.60, 112.67, 119.83, 130.30],
    '云南': [80.81, 77.35, 75.27, 77.48, 78.58, 79.47, 82.45, 86.30, 91.38, 96.33, 101.33, 105.39],
    '西藏': [74.32, 70.98, 69.00, 69.93, 69.96, 76.07, 82.03, 86.08, 93.34, 96.17, 98.87, 105.35],
    '陕西': [96.26, 88.81, 86.26, 86.47, 88.89, 90.21, 90.20, 93.59, 98.10, 103.18, 106.50, 111.76],
    '甘肃': [95.20, 92.64, 85.75, 85.41, 85.01, 86.11, 87.14, 90.39, 91.84, 89.78, 89.34, 90.00],
    '青海': [69.02, 64.55, 65.40, 68.36, 70.75, 71.31, 73.23, 82.55, 86.22, 88.09, 88.71, 92.20],
    '宁夏': [99.90, 98.09, 97.06, 97.05, 97.08, 97.99, 99.57, 103.29, 105.57, 103.56, 103.08, 103.77],
    '新疆': [97.27, 92.13, 89.93, 91.16, 93.39, 94.14, 95.66, 97.02, 100.66, 104.38, 108.85, 112.66],
    '大连市': [127.53, 127.86, 125.98, 122.01, 123.20, 123.97, 130.33, 133.51, 141.03, 141.90, 138.07, 134.99],
    '宁波市': [132.53, 128.27, 128.12, 130.14, 139.07, 145.67, 149.69, 147.43, 153.23, 158.37, 161.93, 163.06],
    '厦门市': [112.40, 112.22, 114.87, 219.25, 227.30, 243.44, 254.68, 253.30, 250.15, 246.08, 237.01, 230.31],
    # 第4批
    '青岛市': [111.81, 110.71, 113.06, 113.91, 114.40, 115.71, 118.40, 120.25, 121.36, 124.85, 130.45, 138.36],
    '深圳市': [597.57, 603.29, 578.65, 534.73, 482.72, 460.55, 474.07, 490.73, 484.91, 436.45, 402.13, 382.65]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# 3. 循环为每个地区/城市进行 ARIMA 预测
forecast_results = {}
fitted_models = {}

print(f"共 {len(locations)} 个地区/城市需要处理。")
print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n")

# ... (ARIMA 拟合和预测的循环代码不变) ...
for i, loc in enumerate(locations):
    print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---")
    series = df[loc]
    try:
        auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                   seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
        if auto_model is None or not hasattr(auto_model, 'order'):
             raise ValueError("auto_arima未能找到合适的模型。")
        print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}")
        print("模型详细参数:")
        print(auto_model.summary())
        print("-" * 60)
        fitted_models[loc] = auto_model
        forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
        forecast_results[loc] = forecast
    except Exception as e:
        print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}")
        print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。")
        forecast_results[loc] = [np.nan] * forecast_horizon
        fitted_models[loc] = None
    finally:
        print("\n")


# 4. 整理并展示预测结果
forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(forecast_df_formatted)
pd.reset_option('display.max_columns')
pd.reset_option('display.width')

# --- 新增：导出到 CSV ---
output_filename = 'arima_forecast_2022_2035.csv'
try:
    # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
    forecast_df_formatted.to_csv(output_filename, encoding='utf-8-sig')
    print(f"\n预测结果已成功导出到文件: {os.path.abspath(output_filename)}") # 打印完整路径
except Exception as e:
    print(f"\n!!! 导出 CSV 文件时出错: {e}")
# --- 结束新增部分 ---


# 5. 可选：绘制历史数据和预测结果
plot_results = False # 设置为 False 则不绘图

if plot_results:
    print("\n--- 正在绘制结果图表 ---")
    # ... (绘图代码不变) ...
    n_locations = len(locations)
    cols_per_row = 3
    n_rows = (n_locations + cols_per_row - 1) // cols_per_row
    fig_width = 15
    fig_height_per_row = 4
    fig_height = n_rows * fig_height_per_row

    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=(fig_width, fig_height), sharex=True, squeeze=False)
    fig.suptitle('各地区/城市比例历史数据与 ARIMA 预测 (2010-2035)', fontsize=16, y=0.99)

    try:
        plt.rcParams['font.sans-serif'] = ['SimHei']
        plt.rcParams['axes.unicode_minus'] = False
    except Exception as font_error:
        print(f"\n注意: 设置中文字体失败: {font_error}")
        print("图表标题和标签可能显示乱码。")

    axes_flat = axes.flatten()

    for i, loc in enumerate(locations):
        ax = axes_flat[i]
        if loc in df.columns:
             df[loc].plot(ax=ax, label='历史数据', marker='o', linestyle='-')
        if loc in forecast_df.columns and forecast_df[loc].notna().any():
            forecast_df[loc].plot(ax=ax, label='ARIMA 预测', linestyle='--', marker='x')
            if fitted_models.get(loc) is not None:
                try:
                    _, conf_int_plot = fitted_models[loc].predict(n_periods=forecast_horizon, return_conf_int=True)
                    conf_int_df = pd.DataFrame(conf_int_plot, index=forecast_index, columns=['lower', 'upper'])
                    conf_int_df['lower'] = conf_int_df['lower'].clip(lower=0)
                    ax.fill_between(conf_int_df.index.to_timestamp(),
                                    conf_int_df['lower'],
                                    conf_int_df['upper'],
                                    color='gray', alpha=0.2, label='95% 置信区间 (≥0)')
                except Exception as plot_ci_error:
                     print(f"绘制 {loc} 的置信区间时出错: {plot_ci_error}")
        ax.set_title(loc)
        ax.set_ylabel('比例 (%)')
        ax.legend(fontsize='small')
        ax.grid(True, linestyle=':', alpha=0.6)

    for j in range(i + 1, len(axes_flat)):
        axes_flat[j].set_visible(False)
    for row in range(n_rows):
        for col in range(cols_per_row):
            ax = axes[row, col]
            if ax.is_visible():
                if row == n_rows - 1:
                    ax.set_xlabel('年份')
                else:
                    ax.tick_params(labelbottom=False)

    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()
# Out:
# 共 36 个地区/城市需要处理。
# 开始为每个地区/城市拟合 ARIMA 模型并预测...
#
# --- 正在处理: 北京 (1/36) ---
# 为 '北京' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -33.683
# Date:                Wed, 26 Mar 2025   AIC                             69.366
# Time:                        12:36:12   BIC                             69.669
# Sample:                    12-31-2010   HQIC                            69.034
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        49.3411     26.923      1.833      0.067      -3.427     102.109
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.73
# Prob(Q):                              0.70   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.52   Skew:                            -0.35
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 天津 (2/36) ---
# 为 '天津' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -26.546
# Date:                Wed, 26 Mar 2025   AIC                             55.091
# Time:                        12:36:12   BIC                             55.394
# Sample:                    12-31-2010   HQIC                            54.760
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        11.8373      6.931      1.708      0.088      -1.746      25.421
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.51   Jarque-Bera (JB):                 0.35
# Prob(Q):                              0.47   Prob(JB):                         0.84
# Heteroskedasticity (H):               0.46   Skew:                             0.15
# Prob(H) (two-sided):                  0.54   Kurtosis:                         2.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河北 (3/36) ---
# 为 '河北' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.479
# Date:                Wed, 26 Mar 2025   AIC                             62.957
# Time:                        12:36:12   BIC                             63.260
# Sample:                    12-31-2010   HQIC                            62.625
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.9936      9.137      2.845      0.004       8.086      43.901
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.16   Jarque-Bera (JB):                 3.67
# Prob(Q):                              0.28   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.17   Skew:                             1.36
# Prob(H) (two-sided):                  0.17   Kurtosis:                         4.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山西 (4/36) ---
# 为 '山西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.831
# Date:                Wed, 26 Mar 2025   AIC                             59.662
# Time:                        12:36:12   BIC                             59.965
# Sample:                    12-31-2010   HQIC                            59.330
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        18.6965      6.067      3.082      0.002       6.806      30.587
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.20   Jarque-Bera (JB):                 2.86
# Prob(Q):                              0.14   Prob(JB):                         0.24
# Heteroskedasticity (H):               0.05   Skew:                             1.25
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 内蒙古 (5/36) ---
# 为 '内蒙古' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.952
# Date:                Wed, 26 Mar 2025   AIC                             49.904
# Time:                        12:36:12   BIC                             50.207
# Sample:                    12-31-2010   HQIC                            49.572
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         7.0466      3.725      1.892      0.059      -0.254      14.347
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.14
# Prob(Q):                              0.98   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.94   Skew:                             0.04
# Prob(H) (two-sided):                  0.96   Kurtosis:                         2.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 辽宁 (6/36) ---
# 为 '辽宁' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -31.339
# Date:                Wed, 26 Mar 2025   AIC                             64.678
# Time:                        12:36:12   BIC                             64.980
# Sample:                    12-31-2010   HQIC                            64.346
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        30.8733     17.440      1.770      0.077      -3.309      65.056
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.29   Jarque-Bera (JB):                 0.24
# Prob(Q):                              0.26   Prob(JB):                         0.89
# Heteroskedasticity (H):               0.27   Skew:                             0.12
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 吉林 (7/36) ---
# 为 '吉林' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.307
# Date:                Wed, 26 Mar 2025   AIC                             62.614
# Time:                        12:36:12   BIC                             62.917
# Sample:                    12-31-2010   HQIC                            62.282
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.1164     10.450      2.403      0.016       4.635      45.598
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.59   Jarque-Bera (JB):                 3.30
# Prob(Q):                              0.44   Prob(JB):                         0.19
# Heteroskedasticity (H):               2.18   Skew:                            -1.35
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 黑龙江 (8/36) ---
# 为 '黑龙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -36.770
# Date:                Wed, 26 Mar 2025   AIC                             75.539
# Time:                        12:36:12   BIC                             75.842
# Sample:                    12-31-2010   HQIC                            75.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        91.4745     33.203      2.755      0.006      26.397     156.552
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.75   Jarque-Bera (JB):                 1.08
# Prob(Q):                              0.19   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.04   Skew:                             0.55
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 上海 (9/36) ---
# 为 '上海' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.030
# Date:                Wed, 26 Mar 2025   AIC                             72.059
# Time:                        12:36:12   BIC                             72.362
# Sample:                    12-31-2010   HQIC                            71.727
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        64.5907     47.316      1.365      0.172     -28.148     157.329
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.53   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.80   Skew:                             0.01
# Prob(H) (two-sided):                  0.86   Kurtosis:                         1.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江苏 (10/36) ---
# 为 '江苏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -21.589
# Date:                Wed, 26 Mar 2025   AIC                             45.178
# Time:                        12:36:12   BIC                             45.481
# Sample:                    12-31-2010   HQIC                            44.846
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         4.3928      1.479      2.970      0.003       1.494       7.291
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.14   Jarque-Bera (JB):                 2.18
# Prob(Q):                              0.28   Prob(JB):                         0.34
# Heteroskedasticity (H):               0.26   Skew:                             1.07
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 浙江 (11/36) ---
# 为 '浙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.813
# Date:                Wed, 26 Mar 2025   AIC                             49.627
# Time:                        12:36:12   BIC                             49.929
# Sample:                    12-31-2010   HQIC                            49.295
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         6.8537      4.466      1.535      0.125      -1.899      15.606
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.75   Prob(JB):                         0.79
# Heteroskedasticity (H):               1.10   Skew:                            -0.09
# Prob(H) (two-sided):                  0.94   Kurtosis:                         1.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 安徽 (12/36) ---
# 为 '安徽' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -26.140
# Date:                Wed, 26 Mar 2025   AIC                             56.281
# Time:                        12:36:12   BIC                             56.886
# Sample:                    12-31-2010   HQIC                            55.617
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7863      0.198      3.979      0.000       0.399       1.174
# sigma2         9.9119      8.053      1.231      0.218      -5.873      25.696
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.44   Jarque-Bera (JB):                 0.86
# Prob(Q):                              0.23   Prob(JB):                         0.65
# Heteroskedasticity (H):               0.42   Skew:                             0.65
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 福建 (13/36) ---
# 为 '福建' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -31.026
# Date:                Wed, 26 Mar 2025   AIC                             70.052
# Time:                        12:36:13   BIC                             71.992
# Sample:                    12-31-2010   HQIC                            69.334
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     15.0542     26.445      0.569      0.569     -36.777      66.886
# ar.L1          1.4890      0.482      3.088      0.002       0.544       2.434
# ar.L2         -0.6392      0.605     -1.057      0.291      -1.825       0.546
# sigma2         8.1685      3.930      2.078      0.038       0.465      15.872
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.10
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                            -1.87
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江西 (14/36) ---
# 为 '江西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.263
# Date:                Wed, 26 Mar 2025   AIC                             62.526
# Time:                        12:36:13   BIC                             62.829
# Sample:                    12-31-2010   HQIC                            62.194
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        24.8965     12.727      1.956      0.050      -0.048      49.841
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.16
# Prob(Q):                              0.76   Prob(JB):                         0.92
# Heteroskedasticity (H):               0.72   Skew:                             0.24
# Prob(H) (two-sided):                  0.80   Kurtosis:                         2.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山东 (15/36) ---
# 为 '山东' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.029
# Date:                Wed, 26 Mar 2025   AIC                             54.058
# Time:                        12:36:13   BIC                             54.663
# Sample:                    12-31-2010   HQIC                            53.394
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.4900      0.963      1.546      0.122      -0.398       3.378
# sigma2         8.7400      3.980      2.196      0.028       0.940      16.540
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.20
# Prob(Q):                              0.89   Prob(JB):                         0.90
# Heteroskedasticity (H):               1.05   Skew:                            -0.35
# Prob(H) (two-sided):                  0.97   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河南 (16/36) ---
# 为 '河南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.484
# Date:                Wed, 26 Mar 2025   AIC                             72.969
# Time:                        12:36:13   BIC                             73.271
# Sample:                    12-31-2010   HQIC                            72.637
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        70.7411     21.516      3.288      0.001      28.571     112.911
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.83   Jarque-Bera (JB):                 3.60
# Prob(Q):                              0.09   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.04   Skew:                             1.12
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖北 (17/36) ---
# 为 '湖北' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -36.091
# Date:                Wed, 26 Mar 2025   AIC                             80.182
# Time:                        12:36:13   BIC                             82.122
# Sample:                    12-31-2010   HQIC                            79.464
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     19.1772      8.223      2.332      0.020       3.061      35.294
# ar.L1          1.6825      0.119     14.182      0.000       1.450       1.915
# ar.L2         -0.8738      0.133     -6.573      0.000      -1.134      -0.613
# sigma2        16.4486      9.773      1.683      0.092      -2.706      35.603
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.31   Prob(JB):                         0.85
# Heteroskedasticity (H):               0.17   Skew:                             0.36
# Prob(H) (two-sided):                  0.11   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖南 (18/36) ---
# 为 '湖南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -22.425
# Date:                Wed, 26 Mar 2025   AIC                             46.851
# Time:                        12:36:13   BIC                             47.154
# Sample:                    12-31-2010   HQIC                            46.519
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         5.1925      2.833      1.833      0.067      -0.361      10.746
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.68   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.27   Skew:                             0.53
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广东 (19/36) ---
# 为 '广东' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -15.903
# Date:                Wed, 26 Mar 2025   AIC                             39.806
# Time:                        12:36:13   BIC                             41.016
# Sample:                    12-31-2010   HQIC                            38.478
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7090      1.008      0.704      0.482      -1.266       2.684
# ar.L1          1.1133      0.323      3.443      0.001       0.479       1.747
# ar.L2         -0.8347      0.129     -6.446      0.000      -1.088      -0.581
# sigma2         1.0600      1.107      0.958      0.338      -1.110       3.229
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 2.94
# Prob(Q):                              0.81   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.43   Skew:                            -1.33
# Prob(H) (two-sided):                  0.78   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广西 (20/36) ---
# 为 '广西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -19.483
# Date:                Wed, 26 Mar 2025   AIC                             40.967
# Time:                        12:36:13   BIC                             41.270
# Sample:                    12-31-2010   HQIC                            40.635
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         2.8830      2.328      1.239      0.216      -1.679       7.445
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.77   Prob(JB):                         0.65
# Heteroskedasticity (H):               1.92   Skew:                            -0.05
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 海南 (21/36) ---
# 为 '海南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -20.622
# Date:                Wed, 26 Mar 2025   AIC                             43.244
# Time:                        12:36:13   BIC                             43.547
# Sample:                    12-31-2010   HQIC                            42.912
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         3.6203      2.176      1.664      0.096      -0.645       7.886
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.08   Jarque-Bera (JB):                 1.10
# Prob(Q):                              0.30   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.15   Skew:                             0.26
# Prob(H) (two-sided):                  0.15   Kurtosis:                         1.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 重庆 (22/36) ---
# 为 '重庆' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.358
# Date:                Wed, 26 Mar 2025   AIC                             58.716
# Time:                        12:36:13   BIC                             59.018
# Sample:                    12-31-2010   HQIC                            58.384
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        17.0080     12.274      1.386      0.166      -7.048      41.064
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.20   Prob(JB):                         0.69
# Heteroskedasticity (H):               2.42   Skew:                            -0.09
# Prob(H) (two-sided):                  0.49   Kurtosis:                         1.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 四川 (23/36) ---
# 为 '四川' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.537
# Date:                Wed, 26 Mar 2025   AIC                             53.075
# Time:                        12:36:13   BIC                             53.377
# Sample:                    12-31-2010   HQIC                            52.743
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.6751      4.459      2.170      0.030       0.937      18.414
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.22   Jarque-Bera (JB):                 0.53
# Prob(Q):                              0.27   Prob(JB):                         0.77
# Heteroskedasticity (H):               0.40   Skew:                             0.55
# Prob(H) (two-sided):                  0.47   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 贵州 (24/36) ---
# 为 '贵州' 找到的最佳 ARIMA 模型阶数: (1, 1, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 -21.403
# Date:                Wed, 26 Mar 2025   AIC                             48.805
# Time:                        12:36:14   BIC                             49.999
# Sample:                    12-31-2010   HQIC                            48.053
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9515      0.106      8.971      0.000       0.744       1.159
# ma.L1          0.8065      0.708      1.139      0.255      -0.581       2.194
# sigma2         1.8979      1.202      1.579      0.114      -0.457       4.253
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.77   Jarque-Bera (JB):                 0.82
# Prob(Q):                              0.38   Prob(JB):                         0.66
# Heteroskedasticity (H):               1.81   Skew:                             0.20
# Prob(H) (two-sided):                  0.58   Kurtosis:                         1.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 云南 (25/36) ---
# 为 '云南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.455
# Date:                Wed, 26 Mar 2025   AIC                             40.910
# Time:                        12:36:14   BIC                             41.516
# Sample:                    12-31-2010   HQIC                            40.247
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7520      0.617      1.218      0.223      -0.458       1.962
# sigma2         2.3471      1.246      1.884      0.060      -0.095       4.789
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 1.51
# Prob(Q):                              0.72   Prob(JB):                         0.47
# Heteroskedasticity (H):               0.25   Skew:                             0.94
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 西藏 (26/36) ---
# 为 '西藏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.498
# Date:                Wed, 26 Mar 2025   AIC                             52.996
# Time:                        12:36:14   BIC                             53.299
# Sample:                    12-31-2010   HQIC                            52.664
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.5997      5.256      1.826      0.068      -0.702      19.902
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.21
# Prob(Q):                              0.20   Prob(JB):                         0.90
# Heteroskedasticity (H):               3.05   Skew:                            -0.08
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 陕西 (27/36) ---
# 为 '陕西' 找到的最佳 ARIMA 模型阶数: (1, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                 -25.998
# Date:                Wed, 26 Mar 2025   AIC                             55.995
# Time:                        12:36:14   BIC                             56.791
# Sample:                    12-31-2010   HQIC                            55.494
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8771      0.139      6.321      0.000       0.605       1.149
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3119      0.451      2.907      0.004       0.427       2.196
# ar.L2         -0.5021      0.385     -1.304      0.192      -1.257       0.253
# sigma2         2.3163      1.669      1.388      0.165      -0.955       5.588
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.14   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.81   Skew:                            -0.15
# Prob(H) (two-sided):                  0.84   Kurtosis:                         1.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 大连市 (32/36) ---
# 为 '大连市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -34.462
# Date:                Wed, 26 Mar 2025   AIC                             76.925
# Time:                        12:36:14   BIC                             78.864
# Sample:                    12-31-2010   HQIC                            76.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9988      0.024     41.692      0.000       0.952       1.046
# ma.L1          0.5881      0.642      0.916      0.359      -0.670       1.846
# ma.L2          0.5414      0.554      0.978      0.328      -0.544       1.627
# sigma2         9.1032      7.754      1.174      0.240      -6.094      24.300
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.54
# Prob(Q):                              0.84   Prob(JB):                         0.76
# Heteroskedasticity (H):               2.79   Skew:                            -0.16
# Prob(H) (two-sided):                  0.34   Kurtosis:                         2.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 宁波市 (33/36) ---
# 为 '宁波市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -33.333
# Date:                Wed, 26 Mar 2025   AIC                             76.665
# Time:                        12:36:15   BIC                             79.090
# Sample:                    12-31-2010   HQIC                            75.768
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     26.4557     96.668      0.274      0.784    -163.011     215.922
# ar.L1          0.8210      0.666      1.232      0.218      -0.485       2.127
# ma.L1          0.8449      1.355      0.624      0.533      -1.811       3.501
# ma.L2          0.5714      0.874      0.654      0.513      -1.142       2.285
# sigma2        11.1114      5.137      2.163      0.031       1.042      21.180
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.96   Prob(JB):                         0.71
# Heteroskedasticity (H):               2.21   Skew:                             0.57
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 厦门市 (34/36) ---
# 为 '厦门市' 找到的最佳 ARIMA 模型阶数: (1, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -58.960
# Date:                Wed, 26 Mar 2025   AIC                            123.919
# Time:                        12:36:15   BIC                            125.374
# Sample:                    12-31-2010   HQIC                           123.380
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     27.9320    103.856      0.269      0.788    -175.621     231.485
# ar.L1          0.8531      0.598      1.427      0.154      -0.319       2.025
# sigma2       972.8598    843.183      1.154      0.249    -679.748    2625.468
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 8.70
# Prob(Q):                              0.86   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.01   Skew:                             1.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 青岛市 (35/36) ---
# 为 '青岛市' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.859
# Date:                Wed, 26 Mar 2025   AIC                             41.719
# Time:                        12:36:15   BIC                             42.324
# Sample:                    12-31-2010   HQIC                            41.055
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9010      0.505      1.785      0.074      -0.088       1.890
# sigma2         2.5447      2.034      1.251      0.211      -1.442       6.532
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.79
# Prob(Q):                              0.99   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.41   Skew:                            -0.03
# Prob(H) (two-sided):                  0.48   Kurtosis:                         1.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 深圳市 (36/36) ---
# 为 '深圳市' 找到的最佳 ARIMA 模型阶数: (3, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(3, 1, 0)   Log Likelihood                 -41.004
# Date:                Wed, 26 Mar 2025   AIC                             92.008
# Time:                        12:36:15   BIC                             93.998
# Sample:                    12-31-2010   HQIC                            90.754
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -26.3866     10.419     -2.533      0.011     -46.808      -5.965
# ar.L1          0.3123      0.551      0.567      0.571      -0.767       1.392
# ar.L2         -0.2314      0.662     -0.349      0.727      -1.529       1.067
# ar.L3         -0.6714      0.579     -1.159      0.246      -1.807       0.464
# sigma2        69.8144     69.285      1.008      0.314     -65.982     205.611
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 0.33
# Prob(Q):                              0.63   Prob(JB):                         0.85
# Heteroskedasticity (H):               1.09   Skew:                             0.36
# Prob(H) (two-sided):                  0.94   Kurtosis:                         2.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# 2030    3.56%  135.26%  138.62%  106.29%  92.72%   78.22%  108.17%  55.67%  60.96%  138.16%  116.34%  41.73%   98.18%   67.05%   223.7%  200.33%   93.84%   117.0%  198.38%  145.42%  132.45%   61.04%  127.11%  220.59%  175.77%  163.67%  137.77%  95.94%  123.61%  109.98%  117.19%  132.18%  151.29%  199.79%   250.1%  278.31%
# 2031   -5.61%  135.64%  141.13%  107.56%  92.92%   74.94%  109.38%  51.88%  57.19%  139.76%  118.19%  33.44%   98.52%    61.8%  242.25%  205.46%   97.27%  117.39%  211.65%  148.69%  135.09%   53.64%  127.47%  228.36%  187.35%  170.15%  139.19%   96.6%   127.1%  110.67%  117.08%  132.02%  150.66%  198.38%  267.02%  246.83%
# 2032  -14.78%  136.02%  143.64%  108.83%  93.12%   71.66%  110.59%  48.09%  53.42%  141.36%  120.04%   25.0%    99.0%   56.55%  262.29%  210.59%  100.83%  117.78%  226.28%  151.96%  137.73%   46.24%  127.83%  235.74%  199.68%  176.63%  140.43%  97.26%  130.59%  111.36%  117.03%  131.85%  150.14%  197.18%  284.84%   211.1%
# 2033  -23.95%   136.4%  146.15%   110.1%  93.32%   68.38%   111.8%   44.3%  49.65%  142.96%  121.89%  16.45%    99.5%    51.3%  283.82%  215.72%  103.83%  118.17%  242.13%  155.23%  140.37%   38.84%  128.19%  242.77%  212.77%  183.11%  141.53%  97.92%  134.08%  112.05%  117.01%  131.69%  149.71%  196.15%  303.56%  188.93%
# 2034  -33.12%  136.78%  148.66%  111.37%  93.52%    65.1%  113.01%  40.51%  45.88%  144.56%  123.74%    7.8%   99.93%   46.05%  306.84%  220.85%  105.76%  118.56%  258.93%   158.5%  143.01%   31.44%  128.55%  249.46%   226.6%  189.59%  142.48%  98.58%  137.57%  112.74%  117.01%  131.53%  149.36%  195.28%  323.18%  185.01%
# 2035  -42.29%  137.16%  151.17%  112.64%  93.72%   61.82%  114.22%  36.72%  42.11%  146.16%  125.59%  -0.92%  100.27%    40.8%  331.35%  225.98%  106.39%  118.95%  276.47%  161.77%  145.65%   24.04%  128.91%  255.82%  241.19%  196.07%  143.32%  99.24%  141.06%  113.43%  117.03%  131.37%  149.07%  194.53%  343.71%  186.53%
#
# 预测结果已成功导出到文件: /Users/annfengdeye/Desktop/3.26下午2点/arima_forecast_2022_2035.csv

# %%
import pandas as pd
import numpy as np
import pmdarima as pm
import warnings
import matplotlib.pyplot as plt # 可选，用于绘图
import os
import sys # <--- 新增导入
import contextlib # <--- 新增导入

warnings.filterwarnings("ignore") # 忽略 ARIMA 拟合中可能出现的警告

# --- 新增：定义标准输出重定向的上下文管理器 ---
@contextlib.contextmanager
def redirect_stdout_to_file(filename, mode='w', encoding='utf-8'):
    """一个临时重定向 sys.stdout 到文件的上下文管理器。"""
    original_stdout = sys.stdout
    try:
        with open(filename, mode, encoding=encoding) as f:
            sys.stdout = f
            yield f # 可以选择性地 yield 文件对象，虽然这里没用到
    finally:
        sys.stdout = original_stdout # 保证无论如何都恢复 stdout
# --- 结束新增部分 ---

# 1. 准备数据 (保持不变)
data = {
    '年份': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2
    '贵州': [89.62, 86.83, 86.88, 87.79, 88.32, 90.12, 93.71, 99.87, 106.60, 112.67, 119.83, 130.30],
    '云南': [80.81, 77.35, 75.27, 77.48, 78.58, 79.47, 82.45, 86.30, 91.38, 96.33, 101.33, 105.39],
    '西藏': [74.32, 70.98, 69.00, 69.93, 69.96, 76.07, 82.03, 86.08, 93.34, 96.17, 98.87, 105.35],
    '陕西': [96.26, 88.81, 86.26, 86.47, 88.89, 90.21, 90.20, 93.59, 98.10, 103.18, 106.50, 111.76],
    '甘肃': [95.20, 92.64, 85.75, 85.41, 85.01, 86.11, 87.14, 90.39, 91.84, 89.78, 89.34, 90.00],
    '青海': [69.02, 64.55, 65.40, 68.36, 70.75, 71.31, 73.23, 82.55, 86.22, 88.09, 88.71, 92.20],
    '宁夏': [99.90, 98.09, 97.06, 97.05, 97.08, 97.99, 99.57, 103.29, 105.57, 103.56, 103.08, 103.77],
    '新疆': [97.27, 92.13, 89.93, 91.16, 93.39, 94.14, 95.66, 97.02, 100.66, 104.38, 108.85, 112.66],
    '大连市': [127.53, 127.86, 125.98, 122.01, 123.20, 123.97, 130.33, 133.51, 141.03, 141.90, 138.07, 134.99],
    '宁波市': [132.53, 128.27, 128.12, 130.14, 139.07, 145.67, 149.69, 147.43, 153.23, 158.37, 161.93, 163.06],
    '厦门市': [112.40, 112.22, 114.87, 219.25, 227.30, 243.44, 254.68, 253.30, 250.15, 246.08, 237.01, 230.31],
    # 第4批 (本次新增)
    '青岛市': [111.81, 110.71, 113.06, 113.91, 114.40, 115.71, 118.40, 120.25, 121.36, 124.85, 130.45, 138.36],
    '深圳市': [597.57, 603.29, 578.65, 534.73, 482.72, 460.55, 474.07, 490.73, 484.91, 436.45, 402.13, 382.65]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数 (保持不变)
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# --- 定义输出文件名 ---
output_log_filename = 'arima_processing_log.txt'
output_csv_filename = 'arima_forecast_2022_2035.csv'

# --- 在重定向前打印一条消息到控制台 ---
print(f"--- 开始处理，所有详细文本输出将写入文件: {output_log_filename} ---")
print(f"--- 最终预测表将导出到 CSV 文件: {output_csv_filename} ---")

# --- 使用上下文管理器重定向输出 ---
try:
    with redirect_stdout_to_file(output_log_filename, encoding='utf-8'):

        # 3. 循环为每个地区/城市进行 ARIMA 预测 (现在 print 会写入文件)
        forecast_results = {}
        fitted_models = {}

        print(f"共 {len(locations)} 个地区/城市需要处理。") # <-- 写入文件
        print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n") # <-- 写入文件

        for i, loc in enumerate(locations):
            print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---") # <-- 写入文件
            series = df[loc]
            try:
                auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                           seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
                if auto_model is None or not hasattr(auto_model, 'order'):
                     raise ValueError("auto_arima未能找到合适的模型。")
                print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}") # <-- 写入文件
                print("模型详细参数:") # <-- 写入文件
                print(auto_model.summary()) # <-- 写入文件 (summary 的输出也会被捕获)
                print("-" * 60) # <-- 写入文件
                fitted_models[loc] = auto_model
                forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
                forecast_results[loc] = forecast
            except Exception as e:
                print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}") # <-- 写入文件
                print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。") # <-- 写入文件
                forecast_results[loc] = [np.nan] * forecast_horizon
                fitted_models[loc] = None
            finally:
                print("\n") # <-- 写入文件


        # 4. 整理并展示预测结果 (现在 print 会写入文件)
        forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
        forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
        forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
        forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

        print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---") # <-- 写入文件

        # 为了确保 DataFrame 完整打印到文件，使用 to_string()
        pd.set_option('display.max_rows', None)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 2000) # 设置足够宽的宽度
        print(forecast_df_formatted.to_string()) # <-- 将完整表格写入文件
        pd.reset_option('display.max_rows')
        pd.reset_option('display.max_columns')
        pd.reset_option('display.width')

        # 导出到 CSV (打印的确认信息也会写入 TXT 文件)
        try:
            # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
            forecast_df_formatted.to_csv(output_csv_filename, encoding='utf-8-sig')
            print(f"\n预测结果已成功导出到 CSV 文件: {os.path.abspath(output_csv_filename)}") # <-- 写入文件
        except Exception as e:
            print(f"\n!!! 导出 CSV 文件时出错: {e}") # <-- 写入文件

        # 打印绘图准备信息 (也会写入 TXT 文件)
        plot_results = True # 设置为 False 则不绘图
        if plot_results:
            print("\n--- 正在准备绘制结果图表 (图表将单独显示)... ---") # <-- 写入文件

    # --- 重定向结束，后续 print 会回到控制台 ---
    print(f"--- 处理完成，详细文本输出已写入: {os.path.abspath(output_log_filename)} ---")

except Exception as global_error:
    # 捕获在重定向期间可能发生的其他未预料错误
    print(f"!!! 脚本执行过程中发生严重错误: {global_error} !!!")
    # 尝试将错误信息追加到日志文件
    try:
        with open(output_log_filename, 'a', encoding='utf-8') as f_err:
             f_err.write(f"\n\n!!! 脚本执行过程中发生严重错误: {global_error} !!!\n")
    except:
        pass # 忽略记录错误时发生的错误
# Out:
# --- 开始处理，所有详细文本输出将写入文件: arima_processing_log.txt ---
# --- 最终预测表将导出到 CSV 文件: arima_forecast_2022_2035.csv ---
# --- 处理完成，详细文本输出已写入: /Users/annfengdeye/Desktop/3.26下午2点/arima_processing_log.txt ---

'海南': [56.63, 72.31, 83.41, 78.5, 82.93, 88.69, 91.6, 92.81, 91.92, 96.17, 93.31, 91.59],
'重庆': [100.5, 104.77, 106.08, 107.18, 107.25, 104.06, 102.29, 100.02, 98.47, 97.12, 94.25, 91.97],
'四川': [93.14, 97.87, 108.15, 103.63, 108.72, 110.33, 108.95, 106.4, 105.63, 102.65, 97.95, 93.17],
'贵州': [58.44, 67.43, 82.82, 74.54, 91.0, 101.92, 108.53, 109.0, 107.27, 107.13, 107.85, 105.53],
'云南': [59.96, 63.48, 70.71, 67.51, 73.29, 74.6, 79.43, 81.12, 83.86, 91.63, 95.23, 97.31],
'西藏': [28.44, 43.03, 57.81, 52.56, 62.49, 67.38, 72.41, 82.02, 92.27, 95.93, 97.43, 96.69],
'陕西': [90.87, 103.25, 117.3, 113.79, 125.79, 127.88, 127.45, 122.74, 118.83, 117.06, 110.27, 120.78],
'甘肃': [43.64, 47.83, 62.2, 56.65, 74.46, 96.29, 100.26, 101.62, 100.31, 102.8, 105.6, 107.44],
'青海': [53.5, 61.94, 70.92, 67.53, 74.73, 81.45, 84.54, 86.52, 85.28, 89.32, 89.83, 87.59],
'宁夏': [53.5, 58.52, 66.81, 63.08, 72.88, 78.71, 88.22, 92.48, 93.65, 94.41, 93.85, 89.92],
'新疆': [63.46, 66.4, 71.58, 69.46, 79.29, 89.55, 136.9, 142.45, 136.85, 118.59, 103.63, 92.53],
'大连市': [109.4, 109.35, 109.23, 108.73, 108.15, 102.72, 99.2, 101.14, 97.27, 96.98, 91.14, 99.85],
'宁波市': [192.29, 197.39, 198.22, 196.96, 232.02, 279.7, 267.52, 217.48, 186.66, 183.85, 179.88, 179.05],
'厦门市': [151.89, 162.83, 172.58, 183.14, 182.79, 177.07, 170.93, 167.4, 155.47, 153.11, 146.2, 147.66],
'青岛市': [89.96, 102.93, 112.71, 112.65, 108.83, 108.34, 103.45, 106.53, 104.86, 103.89, 113.05, 121.38],
'深圳市': [285.58, 277.18, 284.98, 316.08, 303.68, 286.36, 263.83, 260.86, 246.73, 217.35, 191.39, 184.1]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# 3. 循环为每个地区/城市进行 ARIMA 预测
forecast_results = {}
fitted_models = {}

print(f"共 {len(locations)} 个地区/城市需要处理。")
print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n")

# ... (ARIMA 拟合和预测的循环代码不变) ...
for i, loc in enumerate(locations):
    print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---")
    series = df[loc]
    try:
        auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                   seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
        if auto_model is None or not hasattr(auto_model, 'order'):
             raise ValueError("auto_arima未能找到合适的模型。")
        print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}")
        print("模型详细参数:")
        print(auto_model.summary())
        print("-" * 60)
        fitted_models[loc] = auto_model
        forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
        forecast_results[loc] = forecast
    except Exception as e:
        print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}")
        print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。")
        forecast_results[loc] = [np.nan] * forecast_horizon
        fitted_models[loc] = None
    finally:
        print("\n")


# 4. 整理并展示预测结果
forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(forecast_df_formatted)
pd.reset_option('display.max_columns')
pd.reset_option('display.width')

# --- 新增：导出到 CSV ---
output_filename = 'arima_forecast_2022_2035.csv'
try:
    # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
    forecast_df_formatted.to_csv(output_filename, encoding='utf-8-sig')
    print(f"\n预测结果已成功导出到文件: {os.path.abspath(output_filename)}") # 打印完整路径
except Exception as e:
    print(f"\n!!! 导出 CSV 文件时出错: {e}")
# --- 结束新增部分 ---


# 5. 可选：绘制历史数据和预测结果
plot_results = False # 设置为 False 则不绘图

if plot_results:
    print("\n--- 正在绘制结果图表 ---")
    # ... (绘图代码不变) ...
    n_locations = len(locations)
    cols_per_row = 3
    n_rows = (n_locations + cols_per_row - 1) // cols_per_row
    fig_width = 15
    fig_height_per_row = 4
    fig_height = n_rows * fig_height_per_row

    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=(fig_width, fig_height), sharex=True, squeeze=False)
    fig.suptitle('各地区/城市比例历史数据与 ARIMA 预测 (2010-2035)', fontsize=16, y=0.99)

    try:
        plt.rcParams['font.sans-serif'] = ['SimHei']
        plt.rcParams['axes.unicode_minus'] = False
    except Exception as font_error:
        print(f"\n注意: 设置中文字体失败: {font_error}")
        print("图表标题和标签可能显示乱码。")

    axes_flat = axes.flatten()

    for i, loc in enumerate(locations):
        ax = axes_flat[i]
        if loc in df.columns:
             df[loc].plot(ax=ax, label='历史数据', marker='o', linestyle='-')
        if loc in forecast_df.columns and forecast_df[loc].notna().any():
            forecast_df[loc].plot(ax=ax, label='ARIMA 预测', linestyle='--', marker='x')
            if fitted_models.get(loc) is not None:
                try:
                    _, conf_int_plot = fitted_models[loc].predict(n_periods=forecast_horizon, return_conf_int=True)
                    conf_int_df = pd.DataFrame(conf_int_plot, index=forecast_index, columns=['lower', 'upper'])
                    conf_int_df['lower'] = conf_int_df['lower'].clip(lower=0)
                    ax.fill_between(conf_int_df.index.to_timestamp(),
                                    conf_int_df['lower'],
                                    conf_int_df['upper'],
                                    color='gray', alpha=0.2, label='95% 置信区间 (≥0)')
                except Exception as plot_ci_error:
                     print(f"绘制 {loc} 的置信区间时出错: {plot_ci_error}")
        ax.set_title(loc)
        ax.set_ylabel('比例 (%)')
        ax.legend(fontsize='small')
        ax.grid(True, linestyle=':', alpha=0.6)

    for j in range(i + 1, len(axes_flat)):
        axes_flat[j].set_visible(False)
    for row in range(n_rows):
        for col in range(cols_per_row):
            ax = axes[row, col]
            if ax.is_visible():
                if row == n_rows - 1:
                    ax.set_xlabel('年份')
                else:
                    ax.tick_params(labelbottom=False)

    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()
# Out:
# 共 36 个地区/城市需要处理。
# 开始为每个地区/城市拟合 ARIMA 模型并预测...
#
# --- 正在处理: 北京 (1/36) ---
# 为 '北京' 找到的最佳 ARIMA 模型阶数: (0, 2, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 1)   Log Likelihood                 -33.220
# Date:                Wed, 26 Mar 2025   AIC                             70.440
# Time:                        12:42:36   BIC                             71.046
# Sample:                    12-31-2010   HQIC                            69.777
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8209      0.700     -1.173      0.241      -2.193       0.551
# sigma2        40.2669     27.259      1.477      0.140     -13.159      93.693
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.91   Jarque-Bera (JB):                 0.58
# Prob(Q):                              0.34   Prob(JB):                         0.75
# Heteroskedasticity (H):               0.70   Skew:                             0.11
# Prob(H) (two-sided):                  0.77   Kurtosis:                         1.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 天津 (2/36) ---
# 为 '天津' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.390
# Date:                Wed, 26 Mar 2025   AIC                             62.781
# Time:                        12:42:36   BIC                             63.083
# Sample:                    12-31-2010   HQIC                            62.449
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.5386     19.242      1.327      0.184     -12.175      63.252
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):                 0.94
# Prob(Q):                              0.46   Prob(JB):                         0.63
# Heteroskedasticity (H):               0.28   Skew:                             0.22
# Prob(H) (two-sided):                  0.32   Kurtosis:                         1.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河北 (3/36) ---
# 为 '河北' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -23.993
# Date:                Wed, 26 Mar 2025   AIC                             55.986
# Time:                        12:42:36   BIC                             57.196
# Sample:                    12-31-2010   HQIC                            54.658
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -1.4844      1.450     -1.024      0.306      -4.326       1.357
# ar.L1         -1.1999      0.389     -3.083      0.002      -1.963      -0.437
# ar.L2         -0.6197      1.111     -0.558      0.577      -2.798       1.559
# sigma2         5.9548      4.018      1.482      0.138      -1.921      13.831
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):                 0.94
# Prob(Q):                              0.71   Prob(JB):                         0.63
# Heteroskedasticity (H):               1.25   Skew:                            -0.68
# Prob(H) (two-sided):                  0.86   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山西 (4/36) ---
# 为 '山西' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -26.238
# Date:                Wed, 26 Mar 2025   AIC                             56.475
# Time:                        12:42:36   BIC                             57.080
# Sample:                    12-31-2010   HQIC                            55.811
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5111      0.479     -1.068      0.285      -1.449       0.427
# sigma2        10.7978      6.316      1.710      0.087      -1.581      23.176
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 0.95
# Prob(Q):                              0.79   Prob(JB):                         0.62
# Heteroskedasticity (H):               0.10   Skew:                            -0.75
# Prob(H) (two-sided):                  0.09   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 内蒙古 (5/36) ---
# 为 '内蒙古' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -33.369
# Date:                Wed, 26 Mar 2025   AIC                             70.739
# Time:                        12:42:36   BIC                             71.534
# Sample:                    12-31-2010   HQIC                            70.237
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.0364      1.846      1.645      0.100      -0.582       6.654
# sigma2        25.2613     15.012      1.683      0.092      -4.161      54.684
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.81   Jarque-Bera (JB):                 1.02
# Prob(Q):                              0.37   Prob(JB):                         0.60
# Heteroskedasticity (H):               0.19   Skew:                             0.71
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 辽宁 (6/36) ---
# 为 '辽宁' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -36.383
# Date:                Wed, 26 Mar 2025   AIC                             74.765
# Time:                        12:42:36   BIC                             75.163
# Sample:                    12-31-2010   HQIC                            74.515
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        43.6915     25.021      1.746      0.081      -5.350      92.733
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 0.48
# Prob(Q):                              0.79   Prob(JB):                         0.78
# Heteroskedasticity (H):               1.43   Skew:                            -0.25
# Prob(H) (two-sided):                  0.73   Kurtosis:                         2.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 吉林 (7/36) ---
# 为 '吉林' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -33.505
# Date:                Wed, 26 Mar 2025   AIC                             69.011
# Time:                        12:42:36   BIC                             69.409
# Sample:                    12-31-2010   HQIC                            68.760
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.8937     17.822      1.453      0.146      -9.037      60.824
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.80
# Prob(Q):                              0.95   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.37   Skew:                             0.03
# Prob(H) (two-sided):                  0.36   Kurtosis:                         1.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 黑龙江 (8/36) ---
# 为 '黑龙江' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -25.312
# Date:                Wed, 26 Mar 2025   AIC                             54.624
# Time:                        12:42:36   BIC                             55.229
# Sample:                    12-31-2010   HQIC                            53.960
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8643      0.217     -3.980      0.000      -1.290      -0.439
# sigma2         8.0607      7.116      1.133      0.257      -5.887      22.008
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.48   Jarque-Bera (JB):                 0.93
# Prob(Q):                              0.22   Prob(JB):                         0.63
# Heteroskedasticity (H):               0.74   Skew:                            -0.00
# Prob(H) (two-sided):                  0.81   Kurtosis:                         1.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 上海 (9/36) ---
# 为 '上海' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -26.943
# Date:                Wed, 26 Mar 2025   AIC                             55.887
# Time:                        12:42:36   BIC                             56.189
# Sample:                    12-31-2010   HQIC                            55.555
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        12.8171      4.513      2.840      0.005       3.971      21.663
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 3.98
# Prob(Q):                              0.91   Prob(JB):                         0.14
# Heteroskedasticity (H):               0.39   Skew:                            -1.38
# Prob(H) (two-sided):                  0.46   Kurtosis:                         4.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江苏 (10/36) ---
# 为 '江苏' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -29.658
# Date:                Wed, 26 Mar 2025   AIC                             61.316
# Time:                        12:42:36   BIC                             61.714
# Sample:                    12-31-2010   HQIC                            61.066
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        12.8652      6.112      2.105      0.035       0.886      24.844
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.77   Prob(JB):                         0.79
# Heteroskedasticity (H):               0.62   Skew:                             0.48
# Prob(H) (two-sided):                  0.66   Kurtosis:                         2.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 浙江 (11/36) ---
# 为 '浙江' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -20.720
# Date:                Wed, 26 Mar 2025   AIC                             45.439
# Time:                        12:42:37   BIC                             46.044
# Sample:                    12-31-2010   HQIC                            44.775
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6203      0.283     -2.194      0.028      -1.174      -0.066
# sigma2         3.5163      2.325      1.512      0.130      -1.041       8.074
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                 0.79
# Prob(Q):                              0.64   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.07   Skew:                            -0.22
# Prob(H) (two-sided):                  0.06   Kurtosis:                         1.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 安徽 (12/36) ---
# 为 '安徽' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -31.353
# Date:                Wed, 26 Mar 2025   AIC                             64.707
# Time:                        12:42:37   BIC                             65.009
# Sample:                    12-31-2010   HQIC                            64.375
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        30.9631     14.490      2.137      0.033       2.564      59.362
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.68   Jarque-Bera (JB):                 0.75
# Prob(Q):                              0.41   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.03   Skew:                             0.58
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 福建 (13/36) ---
# 为 '福建' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -24.035
# Date:                Wed, 26 Mar 2025   AIC                             54.070
# Time:                        12:42:37   BIC                             54.978
# Sample:                    12-31-2010   HQIC                            53.075
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -1.5258      1.449     -1.053      0.292      -4.365       1.313
# ar.L1         -0.5995      0.603     -0.995      0.320      -1.781       0.582
# sigma2         6.8527      7.446      0.920      0.357      -7.741      21.446
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.28
# Prob(Q):                              0.78   Prob(JB):                         0.87
# Heteroskedasticity (H):               0.36   Skew:                             0.14
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江西 (14/36) ---
# 为 '江西' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -27.688
# Date:                Wed, 26 Mar 2025   AIC                             59.376
# Time:                        12:42:37   BIC                             59.981
# Sample:                    12-31-2010   HQIC                            58.712
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5891      0.270     -2.179      0.029      -1.119      -0.059
# sigma2        14.2551      7.601      1.875      0.061      -0.643      29.153
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.58   Jarque-Bera (JB):                 0.48
# Prob(Q):                              0.44   Prob(JB):                         0.79
# Heteroskedasticity (H):               1.68   Skew:                            -0.18
# Prob(H) (two-sided):                  0.68   Kurtosis:                         1.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山东 (15/36) ---
# 为 '山东' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.146
# Date:                Wed, 26 Mar 2025   AIC                             58.292
# Time:                        12:42:37   BIC                             58.594
# Sample:                    12-31-2010   HQIC                            57.960
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        16.3021     10.047      1.623      0.105      -3.389      35.994
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.39   Jarque-Bera (JB):                 1.32
# Prob(Q):                              0.07   Prob(JB):                         0.52
# Heteroskedasticity (H):               2.06   Skew:                             0.74
# Prob(H) (two-sided):                  0.57   Kurtosis:                         2.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河南 (16/36) ---
# 为 '河南' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -31.873
# Date:                Wed, 26 Mar 2025   AIC                             71.746
# Time:                        12:42:37   BIC                             72.956
# Sample:                    12-31-2010   HQIC                            70.418
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -4.8107      2.984     -1.612      0.107     -10.658       1.037
# ar.L1         -1.2328      0.634     -1.943      0.052      -2.476       0.011
# ar.L2         -0.7665      0.215     -3.567      0.000      -1.188      -0.345
# sigma2        26.9146     24.930      1.080      0.280     -21.946      75.776
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):                 0.90
# Prob(Q):                              0.69   Prob(JB):                         0.64
# Heteroskedasticity (H):               0.23   Skew:                            -0.73
# Prob(H) (two-sided):                  0.26   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖北 (17/36) ---
# 为 '湖北' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -31.179
# Date:                Wed, 26 Mar 2025   AIC                             64.358
# Time:                        12:42:37   BIC                             64.756
# Sample:                    12-31-2010   HQIC                            64.107
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        16.9629      6.874      2.468      0.014       3.490      30.436
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.17   Jarque-Bera (JB):                 0.57
# Prob(Q):                              0.08   Prob(JB):                         0.75
# Heteroskedasticity (H):               0.12   Skew:                             0.52
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖南 (18/36) ---
# 为 '湖南' 找到的最佳 ARIMA 模型阶数: (2, 2, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 1)   Log Likelihood                 -28.068
# Date:                Wed, 26 Mar 2025   AIC                             64.136
# Time:                        12:42:37   BIC                             65.346
# Sample:                    12-31-2010   HQIC                            62.808
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9045      0.653     -1.385      0.166      -2.185       0.376
# ar.L2         -0.5998      0.494     -1.215      0.224      -1.568       0.368
# ma.L1         -0.7125      0.821     -0.867      0.386      -2.322       0.897
# sigma2        11.5160     10.674      1.079      0.281      -9.405      32.437
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.71   Jarque-Bera (JB):                 0.99
# Prob(Q):                              0.19   Prob(JB):                         0.61
# Heteroskedasticity (H):               0.04   Skew:                            -0.73
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广东 (19/36) ---
# 为 '广东' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -37.469
# Date:                Wed, 26 Mar 2025   AIC                             78.938
# Time:                        12:42:37   BIC                             79.543
# Sample:                    12-31-2010   HQIC                            78.274
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6849      0.371     -1.846      0.065      -1.412       0.042
# sigma2        98.7681     63.984      1.544      0.123     -26.638     224.174
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.60   Jarque-Bera (JB):                 0.64
# Prob(Q):                              0.21   Prob(JB):                         0.73
# Heteroskedasticity (H):               1.96   Skew:                            -0.45
# Prob(H) (two-sided):                  0.59   Kurtosis:                         2.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广西 (20/36) ---
# 为 '广西' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -30.155
# Date:                Wed, 26 Mar 2025   AIC                             68.310
# Time:                        12:42:37   BIC                             69.521
# Sample:                    12-31-2010   HQIC                            66.983
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -4.0544      3.161     -1.282      0.200     -10.251       2.142
# ar.L1         -1.3657      0.489     -2.792      0.005      -2.324      -0.407
# ar.L2         -0.8508      0.140     -6.067      0.000      -1.126      -0.576
# sigma2        17.4108     19.243      0.905      0.366     -20.305      55.126
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.36   Jarque-Bera (JB):                 1.00
# Prob(Q):                              0.55   Prob(JB):                         0.61
# Heteroskedasticity (H):               0.39   Skew:                            -0.70
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 海南 (21/36) ---
# 为 '海南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -33.333
# Date:                Wed, 26 Mar 2025   AIC                             68.665
# Time:                        12:42:37   BIC                             68.968
# Sample:                    12-31-2010   HQIC                            68.333
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        45.9996     17.892      2.571      0.010      10.931      81.068
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.45   Jarque-Bera (JB):                 0.40
# Prob(Q):                              0.23   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.21   Skew:                            -0.48
# Prob(H) (two-sided):                  0.24   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 重庆 (22/36) ---
# 为 '重庆' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.963
# Date:                Wed, 26 Mar 2025   AIC                             39.925
# Time:                        12:42:37   BIC                             40.228
# Sample:                    12-31-2010   HQIC                            39.593
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         2.5977      1.169      2.222      0.026       0.306       4.890
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.93   Jarque-Bera (JB):                 0.76
# Prob(Q):                              0.33   Prob(JB):                         0.68
# Heteroskedasticity (H):               0.27   Skew:                            -0.51
# Prob(H) (two-sided):                  0.32   Kurtosis:                         2.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 四川 (23/36) ---
# 为 '四川' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -32.559
# Date:                Wed, 26 Mar 2025   AIC                             67.118
# Time:                        12:42:37   BIC                             67.516
# Sample:                    12-31-2010   HQIC                            66.867
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        21.8000     10.207      2.136      0.033       1.795      41.805
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                 1.44
# Prob(Q):                              0.64   Prob(JB):                         0.49
# Heteroskedasticity (H):               0.31   Skew:                             0.87
# Prob(H) (two-sided):                  0.29   Kurtosis:                         2.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 贵州 (24/36) ---
# 为 '贵州' 找到的最佳 ARIMA 模型阶数: (0, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -37.851
# Date:                Wed, 26 Mar 2025   AIC                             79.702
# Time:                        12:42:37   BIC                             80.497
# Sample:                    12-31-2010   HQIC                            79.200
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      4.2809      2.325      1.841      0.066      -0.277       8.838
# sigma2        57.0588     36.743      1.553      0.120     -14.957     129.075
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.61
# Prob(Q):                              0.70   Prob(JB):                         0.74
# Heteroskedasticity (H):               0.25   Skew:                             0.19
# Prob(H) (two-sided):                  0.21   Kurtosis:                         1.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 云南 (25/36) ---
# 为 '云南' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -26.303
# Date:                Wed, 26 Mar 2025   AIC                             58.606
# Time:                        12:42:38   BIC                             59.513
# Sample:                    12-31-2010   HQIC                            57.610
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1283      0.585     -1.928      0.054      -2.275       0.019
# ar.L2         -0.5978      0.369     -1.621      0.105      -1.320       0.125
# sigma2         9.6329      8.336      1.156      0.248      -6.704      25.970
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.42   Jarque-Bera (JB):                 0.39
# Prob(Q):                              0.52   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.77   Skew:                            -0.39
# Prob(H) (two-sided):                  0.83   Kurtosis:                         2.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 西藏 (26/36) ---
# 为 '西藏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.653
# Date:                Wed, 26 Mar 2025   AIC                             73.305
# Time:                        12:42:38   BIC                             73.608
# Sample:                    12-31-2010   HQIC                            72.973
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        73.1595     26.469      2.764      0.006      21.281     125.038
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.03   Jarque-Bera (JB):                 0.48
# Prob(Q):                              0.04   Prob(JB):                         0.79
# Heteroskedasticity (H):               0.08   Skew:                            -0.27
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 陕西 (27/36) ---
# 为 '陕西' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# ...
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -43.668
# Date:                Wed, 26 Mar 2025   AIC                             89.335
# Time:                        12:42:38   BIC                             89.638
# Sample:                    12-31-2010   HQIC                            89.004
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       363.4517    137.552      2.642      0.008      93.854     633.049
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.20   Jarque-Bera (JB):                 0.27
# Prob(Q):                              0.27   Prob(JB):                         0.87
# Heteroskedasticity (H):               0.93   Skew:                            -0.13
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 大连市 (32/36) ---
# 为 '大连市' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -29.418
# Date:                Wed, 26 Mar 2025   AIC                             62.836
# Time:                        12:42:38   BIC                             63.441
# Sample:                    12-31-2010   HQIC                            62.172
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8048      0.355     -2.269      0.023      -1.500      -0.110
# sigma2        18.9424     10.036      1.887      0.059      -0.728      38.612
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):                 2.48
# Prob(Q):                              0.53   Prob(JB):                         0.29
# Heteroskedasticity (H):             322.35   Skew:                             1.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 宁波市 (33/36) ---
# 为 '宁波市' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -47.410
# Date:                Wed, 26 Mar 2025   AIC                             96.820
# Time:                        12:42:38   BIC                             97.123
# Sample:                    12-31-2010   HQIC                            96.488
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       768.2300    347.924      2.208      0.027      86.311    1450.149
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 1.15
# Prob(Q):                              0.43   Prob(JB):                         0.56
# Heteroskedasticity (H):               0.59   Skew:                            -0.83
# Prob(H) (two-sided):                  0.68   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 厦门市 (34/36) ---
# 为 '厦门市' 找到的最佳 ARIMA 模型阶数: (3, 0, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(3, 0, 1)   Log Likelihood                 -32.487
# Date:                Wed, 26 Mar 2025   AIC                             76.975
# Time:                        12:42:38   BIC                             79.884
# Sample:                    12-31-2010   HQIC                            75.897
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     63.5352     26.692      2.380      0.017      11.221     115.850
# ar.L1          1.2580      0.451      2.792      0.005       0.375       2.141
# ar.L2         -0.1816      0.848     -0.214      0.830      -1.844       1.481
# ar.L3         -0.4643      0.477     -0.973      0.331      -1.400       0.471
# ma.L1         -0.9680      8.486     -0.114      0.909     -17.601      15.665
# sigma2         6.6353     57.785      0.115      0.909    -106.621     119.891
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.25   Jarque-Bera (JB):                 0.55
# Prob(Q):                              0.61   Prob(JB):                         0.76
# Heteroskedasticity (H):               0.56   Skew:                             0.29
# Prob(H) (two-sided):                  0.59   Kurtosis:                         2.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 青岛市 (35/36) ---
# 为 '青岛市' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -31.843
# Date:                Wed, 26 Mar 2025   AIC                             65.685
# Time:                        12:42:38   BIC                             65.988
# Sample:                    12-31-2010   HQIC                            65.354
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        34.1468     20.003      1.707      0.088      -5.059      73.352
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):                 0.50
# Prob(Q):                              0.69   Prob(JB):                         0.78
# Heteroskedasticity (H):               0.86   Skew:                             0.42
# Prob(H) (two-sided):                  0.90   Kurtosis:                         2.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 深圳市 (36/36) ---
# 为 '深圳市' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -51.111
# Date:                Wed, 26 Mar 2025   AIC                            110.222
# Time:                        12:42:39   BIC                            112.162
# Sample:                    12-31-2010   HQIC                           109.504
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     35.1588     70.128      0.501      0.616    -102.290     172.608
# ar.L1          1.3972      0.279      5.013      0.000       0.851       1.943
# ar.L2         -0.5361      0.449     -1.194      0.232      -1.416       0.344
# sigma2       239.3229    133.608      1.791      0.073     -22.544     501.190
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.79
# Prob(Q):                              0.78   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.64   Skew:                             0.58
# Prob(H) (two-sided):                  0.67   Kurtosis:                         2.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
'四川': [93.14, 97.87, 108.15, 103.63, 108.72, 110.33, 108.95, 106.4, 105.63, 102.65, 97.95, 93.17],
'贵州': [58.44, 67.43, 82.82, 74.54, 91.0, 101.92, 108.53, 109.0, 107.27, 107.13, 107.85, 105.53],
'云南': [59.96, 63.48, 70.71, 67.51, 73.29, 74.6, 79.43, 81.12, 83.86, 91.63, 95.23, 97.31],
'西藏': [28.44, 43.03, 57.81, 52.56, 62.49, 67.38, 72.41, 82.02, 92.27, 95.93, 97.43, 96.69],
'陕西': [90.87, 103.25, 117.3, 113.79, 125.79, 127.88, 127.45, 122.74, 118.83, 117.06, 110.27, 120.78],
'甘肃': [43.64, 47.83, 62.2, 56.65, 74.46, 96.29, 100.26, 101.62, 100.31, 102.8, 105.6, 107.44],
'青海': [53.5, 61.94, 70.92, 67.53, 74.73, 81.45, 84.54, 86.52, 85.28, 89.32, 89.83, 87.59],
'宁夏': [53.5, 58.52, 66.81, 63.08, 72.88, 78.71, 88.22, 92.48, 93.65, 94.41, 93.85, 89.92],
'新疆': [63.46, 66.4, 71.58, 69.46, 79.29, 89.55, 136.9, 142.45, 136.85, 118.59, 103.63, 92.53],
'大连市': [109.4, 109.35, 109.23, 108.73, 108.15, 102.72, 99.2, 101.14, 97.27, 96.98, 91.14, 99.85],
'宁波市': [192.29, 197.39, 198.22, 196.96, 232.02, 279.7, 267.52, 217.48, 186.66, 183.85, 179.88, 179.05],
'厦门市': [151.89, 162.83, 172.58, 183.14, 182.79, 177.07, 170.93, 167.4, 155.47, 153.11, 146.2, 147.66],
'青岛市': [89.96, 102.93, 112.71, 112.65, 108.83, 108.34, 103.45, 106.53, 104.86, 103.89, 113.05, 121.38],
'深圳市': [285.58, 277.18, 284.98, 316.08, 303.68, 286.36, 263.83, 260.86, 246.73, 217.35, 191.39, 184.1]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数 (保持不变)
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# --- 定义输出文件名 ---
output_log_filename = 'arima_processing_log.txt'
output_csv_filename = 'arima_forecast_2022_2035.csv'

# --- 在重定向前打印一条消息到控制台 ---
print(f"--- 开始处理，所有详细文本输出将写入文件: {output_log_filename} ---")
print(f"--- 最终预测表将导出到 CSV 文件: {output_csv_filename} ---")

# --- 使用上下文管理器重定向输出 ---
try:
    with redirect_stdout_to_file(output_log_filename, encoding='utf-8'):

        # 3. 循环为每个地区/城市进行 ARIMA 预测 (现在 print 会写入文件)
        forecast_results = {}
        fitted_models = {}

        print(f"共 {len(locations)} 个地区/城市需要处理。") # <-- 写入文件
        print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n") # <-- 写入文件

        for i, loc in enumerate(locations):
            print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---") # <-- 写入文件
            series = df[loc]
            try:
                auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                           seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
                if auto_model is None or not hasattr(auto_model, 'order'):
                     raise ValueError("auto_arima未能找到合适的模型。")
                print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}") # <-- 写入文件
                print("模型详细参数:") # <-- 写入文件
                print(auto_model.summary()) # <-- 写入文件 (summary 的输出也会被捕获)
                print("-" * 60) # <-- 写入文件
                fitted_models[loc] = auto_model
                forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
                forecast_results[loc] = forecast
            except Exception as e:
                print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}") # <-- 写入文件
                print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。") # <-- 写入文件
                forecast_results[loc] = [np.nan] * forecast_horizon
                fitted_models[loc] = None
            finally:
                print("\n") # <-- 写入文件


        # 4. 整理并展示预测结果 (现在 print 会写入文件)
        forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
        forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
        forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
        forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

        print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---") # <-- 写入文件

        # 为了确保 DataFrame 完整打印到文件，使用 to_string()
        pd.set_option('display.max_rows', None)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 2000) # 设置足够宽的宽度
        print(forecast_df_formatted.to_string()) # <-- 将完整表格写入文件
        pd.reset_option('display.max_rows')
        pd.reset_option('display.max_columns')
        pd.reset_option('display.width')

        # 导出到 CSV (打印的确认信息也会写入 TXT 文件)
        try:
            # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
            forecast_df_formatted.to_csv(output_csv_filename, encoding='utf-8-sig')
            print(f"\n预测结果已成功导出到 CSV 文件: {os.path.abspath(output_csv_filename)}") # <-- 写入文件
        except Exception as e:
            print(f"\n!!! 导出 CSV 文件时出错: {e}") # <-- 写入文件

        # 打印绘图准备信息 (也会写入 TXT 文件)
        plot_results = True # 设置为 False 则不绘图
        if plot_results:
            print("\n--- 正在准备绘制结果图表 (图表将单独显示)... ---") # <-- 写入文件

    # --- 重定向结束，后续 print 会回到控制台 ---
    print(f"--- 处理完成，详细文本输出已写入: {os.path.abspath(output_log_filename)} ---")

except Exception as global_error:
    # 捕获在重定向期间可能发生的其他未预料错误
    print(f"!!! 脚本执行过程中发生严重错误: {global_error} !!!")
    # 尝试将错误信息追加到日志文件
    try:
        with open(output_log_filename, 'a', encoding='utf-8') as f_err:
             f_err.write(f"\n\n!!! 脚本执行过程中发生严重错误: {global_error} !!!\n")
    except:
        pass # 忽略记录错误时发生的错误
# Out:
# --- 开始处理，所有详细文本输出将写入文件: arima_processing_log.txt ---
# --- 最终预测表将导出到 CSV 文件: arima_forecast_2022_2035.csv ---
# --- 处理完成，详细文本输出已写入: /Users/annfengdeye/Desktop/3.26下午2点/arima_processing_log.txt ---

'海南': [90.19, 85.91, 85.1, 86.79, 87.93, 88.4, 91.6, 97.08, 101.23, 103.81, 106.05, 108.69],
'重庆': [102.75, 100.41, 101.57, 106.55, 114.16, 121.6, 124.25, 125.97, 133.25, 137.74, 135.04, 127.64],
'四川': [81.0, 79.1, 76.08, 79.77, 84.6, 93.11, 102.9, 113.31, 119.91, 122.47, 123.51, 123.87],
'贵州': [89.62, 86.83, 86.88, 87.79, 88.32, 90.12, 93.71, 99.87, 106.6, 112.67, 119.83, 130.3],
'云南': [80.81, 77.35, 75.27, 77.48, 78.58, 79.47, 82.45, 86.3, 91.38, 96.33, 101.33, 105.39],
'西藏': [74.32, 70.98, 69.0, 69.93, 69.96, 76.07, 82.03, 86.08, 93.34, 96.17, 98.87, 105.35],
'陕西': [96.26, 88.81, 86.26, 86.47, 88.89, 90.21, 90.2, 93.59, 98.1, 103.18, 106.5, 111.76],
'甘肃': [95.2, 92.64, 85.75, 85.41, 85.01, 86.11, 87.14, 90.39, 91.84, 89.78, 89.34, 90.0],
'青海': [69.02, 64.55, 65.4, 68.36, 70.75, 71.31, 73.23, 82.55, 86.22, 88.09, 88.71, 92.2],
'宁夏': [99.9, 98.09, 97.06, 97.05, 97.08, 97.99, 99.57, 103.29, 105.57, 103.56, 103.08, 103.77],
'新疆': [97.27, 92.13, 89.93, 91.16, 93.39, 94.14, 95.66, 97.02, 100.66, 104.38, 108.85, 112.66],
'大连市': [127.53, 127.86, 125.98, 122.01, 123.2, 123.97, 130.33, 133.51, 141.03, 141.9, 138.07, 134.99],
'宁波市': [132.53, 128.27, 128.12, 130.14, 139.07, 145.67, 149.69, 147.43, 153.23, 158.37, 161.93, 163.06],
'厦门市': [112.4, 112.22, 114.87, 219.25, 227.3, 243.44, 254.68, 253.3, 250.15, 246.08, 237.01, 230.31],
'青岛市': [111.81, 110.71, 113.06, 113.91, 114.4, 115.71, 118.4, 120.25, 121.36, 124.85, 130.45, 138.36],
'深圳市': [597.57, 603.29, 578.65, 534.73, 482.72, 460.55, 474.07, 490.73, 484.91, 436.45, 402.13, 382.65]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# 3. 循环为每个地区/城市进行 ARIMA 预测
forecast_results = {}
fitted_models = {}

print(f"共 {len(locations)} 个地区/城市需要处理。")
print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n")

# ... (ARIMA 拟合和预测的循环代码不变) ...
for i, loc in enumerate(locations):
    print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---")
    series = df[loc]
    try:
        auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                   seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
        if auto_model is None or not hasattr(auto_model, 'order'):
             raise ValueError("auto_arima未能找到合适的模型。")
        print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}")
        print("模型详细参数:")
        print(auto_model.summary())
        print("-" * 60)
        fitted_models[loc] = auto_model
        forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
        forecast_results[loc] = forecast
    except Exception as e:
        print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}")
        print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。")
        forecast_results[loc] = [np.nan] * forecast_horizon
        fitted_models[loc] = None
    finally:
        print("\n")


# 4. 整理并展示预测结果
forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
print(forecast_df_formatted)
pd.reset_option('display.max_columns')
pd.reset_option('display.width')

# --- 新增：导出到 CSV ---
output_filename = 'arima_forecast_2022_2035.csv'
try:
    # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
    forecast_df_formatted.to_csv(output_filename, encoding='utf-8-sig')
    print(f"\n预测结果已成功导出到文件: {os.path.abspath(output_filename)}") # 打印完整路径
except Exception as e:
    print(f"\n!!! 导出 CSV 文件时出错: {e}")
# --- 结束新增部分 ---


# 5. 可选：绘制历史数据和预测结果
plot_results = False # 设置为 False 则不绘图

if plot_results:
    print("\n--- 正在绘制结果图表 ---")
    # ... (绘图代码不变) ...
    n_locations = len(locations)
    cols_per_row = 3
    n_rows = (n_locations + cols_per_row - 1) // cols_per_row
    fig_width = 15
    fig_height_per_row = 4
    fig_height = n_rows * fig_height_per_row

    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=(fig_width, fig_height), sharex=True, squeeze=False)
    fig.suptitle('各地区/城市比例历史数据与 ARIMA 预测 (2010-2035)', fontsize=16, y=0.99)

    try:
        plt.rcParams['font.sans-serif'] = ['SimHei']
        plt.rcParams['axes.unicode_minus'] = False
    except Exception as font_error:
        print(f"\n注意: 设置中文字体失败: {font_error}")
        print("图表标题和标签可能显示乱码。")

    axes_flat = axes.flatten()

    for i, loc in enumerate(locations):
        ax = axes_flat[i]
        if loc in df.columns:
             df[loc].plot(ax=ax, label='历史数据', marker='o', linestyle='-')
        if loc in forecast_df.columns and forecast_df[loc].notna().any():
            forecast_df[loc].plot(ax=ax, label='ARIMA 预测', linestyle='--', marker='x')
            if fitted_models.get(loc) is not None:
                try:
                    _, conf_int_plot = fitted_models[loc].predict(n_periods=forecast_horizon, return_conf_int=True)
                    conf_int_df = pd.DataFrame(conf_int_plot, index=forecast_index, columns=['lower', 'upper'])
                    conf_int_df['lower'] = conf_int_df['lower'].clip(lower=0)
                    ax.fill_between(conf_int_df.index.to_timestamp(),
                                    conf_int_df['lower'],
                                    conf_int_df['upper'],
                                    color='gray', alpha=0.2, label='95% 置信区间 (≥0)')
                except Exception as plot_ci_error:
                     print(f"绘制 {loc} 的置信区间时出错: {plot_ci_error}")
        ax.set_title(loc)
        ax.set_ylabel('比例 (%)')
        ax.legend(fontsize='small')
        ax.grid(True, linestyle=':', alpha=0.6)

    for j in range(i + 1, len(axes_flat)):
        axes_flat[j].set_visible(False)
    for row in range(n_rows):
        for col in range(cols_per_row):
            ax = axes[row, col]
            if ax.is_visible():
                if row == n_rows - 1:
                    ax.set_xlabel('年份')
                else:
                    ax.tick_params(labelbottom=False)

    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()
# Out:
# 共 36 个地区/城市需要处理。
# 开始为每个地区/城市拟合 ARIMA 模型并预测...
#
# --- 正在处理: 北京 (1/36) ---
# 为 '北京' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -33.683
# Date:                Wed, 26 Mar 2025   AIC                             69.366
# Time:                        13:00:30   BIC                             69.669
# Sample:                    12-31-2010   HQIC                            69.034
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        49.3411     26.923      1.833      0.067      -3.427     102.109
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.73
# Prob(Q):                              0.70   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.52   Skew:                            -0.35
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 天津 (2/36) ---
# 为 '天津' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -26.546
# Date:                Wed, 26 Mar 2025   AIC                             55.091
# Time:                        13:00:30   BIC                             55.394
# Sample:                    12-31-2010   HQIC                            54.760
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        11.8373      6.931      1.708      0.088      -1.746      25.421
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.51   Jarque-Bera (JB):                 0.35
# Prob(Q):                              0.47   Prob(JB):                         0.84
# Heteroskedasticity (H):               0.46   Skew:                             0.15
# Prob(H) (two-sided):                  0.54   Kurtosis:                         2.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河北 (3/36) ---
# 为 '河北' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.479
# Date:                Wed, 26 Mar 2025   AIC                             62.957
# Time:                        13:00:30   BIC                             63.260
# Sample:                    12-31-2010   HQIC                            62.625
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.9936      9.137      2.845      0.004       8.086      43.901
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.16   Jarque-Bera (JB):                 3.67
# Prob(Q):                              0.28   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.17   Skew:                             1.36
# Prob(H) (two-sided):                  0.17   Kurtosis:                         4.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山西 (4/36) ---
# 为 '山西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.831
# Date:                Wed, 26 Mar 2025   AIC                             59.662
# Time:                        13:00:30   BIC                             59.965
# Sample:                    12-31-2010   HQIC                            59.330
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        18.6965      6.067      3.082      0.002       6.806      30.587
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.20   Jarque-Bera (JB):                 2.86
# Prob(Q):                              0.14   Prob(JB):                         0.24
# Heteroskedasticity (H):               0.05   Skew:                             1.25
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 内蒙古 (5/36) ---
# 为 '内蒙古' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.952
# Date:                Wed, 26 Mar 2025   AIC                             49.904
# Time:                        13:00:30   BIC                             50.207
# Sample:                    12-31-2010   HQIC                            49.572
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         7.0466      3.725      1.892      0.059      -0.254      14.347
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.14
# Prob(Q):                              0.98   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.94   Skew:                             0.04
# Prob(H) (two-sided):                  0.96   Kurtosis:                         2.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 辽宁 (6/36) ---
# 为 '辽宁' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -31.339
# Date:                Wed, 26 Mar 2025   AIC                             64.678
# Time:                        13:00:30   BIC                             64.980
# Sample:                    12-31-2010   HQIC                            64.346
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        30.8733     17.440      1.770      0.077      -3.309      65.056
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.29   Jarque-Bera (JB):                 0.24
# Prob(Q):                              0.26   Prob(JB):                         0.89
# Heteroskedasticity (H):               0.27   Skew:                             0.12
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 吉林 (7/36) ---
# 为 '吉林' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.307
# Date:                Wed, 26 Mar 2025   AIC                             62.614
# Time:                        13:00:30   BIC                             62.917
# Sample:                    12-31-2010   HQIC                            62.282
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        25.1164     10.450      2.403      0.016       4.635      45.598
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.59   Jarque-Bera (JB):                 3.30
# Prob(Q):                              0.44   Prob(JB):                         0.19
# Heteroskedasticity (H):               2.18   Skew:                            -1.35
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 黑龙江 (8/36) ---
# 为 '黑龙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -36.770
# Date:                Wed, 26 Mar 2025   AIC                             75.539
# Time:                        13:00:30   BIC                             75.842
# Sample:                    12-31-2010   HQIC                            75.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        91.4745     33.203      2.755      0.006      26.397     156.552
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.75   Jarque-Bera (JB):                 1.08
# Prob(Q):                              0.19   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.04   Skew:                             0.55
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 上海 (9/36) ---
# 为 '上海' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.030
# Date:                Wed, 26 Mar 2025   AIC                             72.059
# Time:                        13:00:30   BIC                             72.362
# Sample:                    12-31-2010   HQIC                            71.727
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        64.5907     47.316      1.365      0.172     -28.148     157.329
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.53   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.80   Skew:                             0.01
# Prob(H) (two-sided):                  0.86   Kurtosis:                         1.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江苏 (10/36) ---
# 为 '江苏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -21.589
# Date:                Wed, 26 Mar 2025   AIC                             45.178
# Time:                        13:00:30   BIC                             45.481
# Sample:                    12-31-2010   HQIC                            44.846
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         4.3928      1.479      2.970      0.003       1.494       7.291
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.14   Jarque-Bera (JB):                 2.18
# Prob(Q):                              0.28   Prob(JB):                         0.34
# Heteroskedasticity (H):               0.26   Skew:                             1.07
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 浙江 (11/36) ---
# 为 '浙江' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -23.813
# Date:                Wed, 26 Mar 2025   AIC                             49.627
# Time:                        13:00:30   BIC                             49.929
# Sample:                    12-31-2010   HQIC                            49.295
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         6.8537      4.466      1.535      0.125      -1.899      15.606
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.75   Prob(JB):                         0.79
# Heteroskedasticity (H):               1.10   Skew:                            -0.09
# Prob(H) (two-sided):                  0.94   Kurtosis:                         1.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 安徽 (12/36) ---
# 为 '安徽' 找到的最佳 ARIMA 模型阶数: (1, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 2, 0)   Log Likelihood                 -26.140
# Date:                Wed, 26 Mar 2025   AIC                             56.281
# Time:                        13:00:30   BIC                             56.886
# Sample:                    12-31-2010   HQIC                            55.617
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7863      0.198      3.979      0.000       0.399       1.174
# sigma2         9.9119      8.053      1.231      0.218      -5.873      25.696
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.44   Jarque-Bera (JB):                 0.86
# Prob(Q):                              0.23   Prob(JB):                         0.65
# Heteroskedasticity (H):               0.42   Skew:                             0.65
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 福建 (13/36) ---
# 为 '福建' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -31.026
# Date:                Wed, 26 Mar 2025   AIC                             70.052
# Time:                        13:00:31   BIC                             71.992
# Sample:                    12-31-2010   HQIC                            69.334
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     15.0542     26.445      0.569      0.569     -36.777      66.886
# ar.L1          1.4890      0.482      3.088      0.002       0.544       2.434
# ar.L2         -0.6392      0.605     -1.057      0.291      -1.825       0.546
# sigma2         8.1685      3.930      2.078      0.038       0.465      15.872
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.10
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                            -1.87
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 江西 (14/36) ---
# 为 '江西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -30.263
# Date:                Wed, 26 Mar 2025   AIC                             62.526
# Time:                        13:00:31   BIC                             62.829
# Sample:                    12-31-2010   HQIC                            62.194
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        24.8965     12.727      1.956      0.050      -0.048      49.841
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 0.16
# Prob(Q):                              0.76   Prob(JB):                         0.92
# Heteroskedasticity (H):               0.72   Skew:                             0.24
# Prob(H) (two-sided):                  0.80   Kurtosis:                         2.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 山东 (15/36) ---
# 为 '山东' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.029
# Date:                Wed, 26 Mar 2025   AIC                             54.058
# Time:                        13:00:31   BIC                             54.663
# Sample:                    12-31-2010   HQIC                            53.394
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.4900      0.963      1.546      0.122      -0.398       3.378
# sigma2         8.7400      3.980      2.196      0.028       0.940      16.540
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.20
# Prob(Q):                              0.89   Prob(JB):                         0.90
# Heteroskedasticity (H):               1.05   Skew:                            -0.35
# Prob(H) (two-sided):                  0.97   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 河南 (16/36) ---
# 为 '河南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -35.484
# Date:                Wed, 26 Mar 2025   AIC                             72.969
# Time:                        13:00:31   BIC                             73.271
# Sample:                    12-31-2010   HQIC                            72.637
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        70.7411     21.516      3.288      0.001      28.571     112.911
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.83   Jarque-Bera (JB):                 3.60
# Prob(Q):                              0.09   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.04   Skew:                             1.12
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖北 (17/36) ---
# 为 '湖北' 找到的最佳 ARIMA 模型阶数: (2, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -36.091
# Date:                Wed, 26 Mar 2025   AIC                             80.182
# Time:                        13:00:31   BIC                             82.122
# Sample:                    12-31-2010   HQIC                            79.464
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     19.1772      8.223      2.332      0.020       3.061      35.294
# ar.L1          1.6825      0.119     14.182      0.000       1.450       1.915
# ar.L2         -0.8738      0.133     -6.573      0.000      -1.134      -0.613
# sigma2        16.4486      9.773      1.683      0.092      -2.706      35.603
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.31   Prob(JB):                         0.85
# Heteroskedasticity (H):               0.17   Skew:                             0.36
# Prob(H) (two-sided):                  0.11   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 湖南 (18/36) ---
# 为 '湖南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -22.425
# Date:                Wed, 26 Mar 2025   AIC                             46.851
# Time:                        13:00:31   BIC                             47.154
# Sample:                    12-31-2010   HQIC                            46.519
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         5.1925      2.833      1.833      0.067      -0.361      10.746
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.68   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.27   Skew:                             0.53
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广东 (19/36) ---
# 为 '广东' 找到的最佳 ARIMA 模型阶数: (2, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                 -15.903
# Date:                Wed, 26 Mar 2025   AIC                             39.806
# Time:                        13:00:31   BIC                             41.016
# Sample:                    12-31-2010   HQIC                            38.478
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7090      1.008      0.704      0.482      -1.266       2.684
# ar.L1          1.1133      0.323      3.443      0.001       0.479       1.747
# ar.L2         -0.8347      0.129     -6.446      0.000      -1.088      -0.581
# sigma2         1.0600      1.107      0.958      0.338      -1.110       3.229
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 2.94
# Prob(Q):                              0.81   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.43   Skew:                            -1.33
# Prob(H) (two-sided):                  0.78   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 广西 (20/36) ---
# 为 '广西' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -19.483
# Date:                Wed, 26 Mar 2025   AIC                             40.967
# Time:                        13:00:31   BIC                             41.270
# Sample:                    12-31-2010   HQIC                            40.635
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         2.8830      2.328      1.239      0.216      -1.679       7.445
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.77   Prob(JB):                         0.65
# Heteroskedasticity (H):               1.92   Skew:                            -0.05
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 海南 (21/36) ---
# 为 '海南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -20.622
# Date:                Wed, 26 Mar 2025   AIC                             43.244
# Time:                        13:00:31   BIC                             43.547
# Sample:                    12-31-2010   HQIC                            42.912
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         3.6203      2.176      1.664      0.096      -0.645       7.886
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.08   Jarque-Bera (JB):                 1.10
# Prob(Q):                              0.30   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.15   Skew:                             0.26
# Prob(H) (two-sided):                  0.15   Kurtosis:                         1.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 重庆 (22/36) ---
# 为 '重庆' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -28.358
# Date:                Wed, 26 Mar 2025   AIC                             58.716
# Time:                        13:00:31   BIC                             59.018
# Sample:                    12-31-2010   HQIC                            58.384
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        17.0080     12.274      1.386      0.166      -7.048      41.064
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.20   Prob(JB):                         0.69
# Heteroskedasticity (H):               2.42   Skew:                            -0.09
# Prob(H) (two-sided):                  0.49   Kurtosis:                         1.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 四川 (23/36) ---
# 为 '四川' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.537
# Date:                Wed, 26 Mar 2025   AIC                             53.075
# Time:                        13:00:31   BIC                             53.377
# Sample:                    12-31-2010   HQIC                            52.743
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.6751      4.459      2.170      0.030       0.937      18.414
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.22   Jarque-Bera (JB):                 0.53
# Prob(Q):                              0.27   Prob(JB):                         0.77
# Heteroskedasticity (H):               0.40   Skew:                             0.55
# Prob(H) (two-sided):                  0.47   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 贵州 (24/36) ---
# 为 '贵州' 找到的最佳 ARIMA 模型阶数: (1, 1, 1)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 -21.403
# Date:                Wed, 26 Mar 2025   AIC                             48.805
# Time:                        13:00:31   BIC                             49.999
# Sample:                    12-31-2010   HQIC                            48.053
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9515      0.106      8.971      0.000       0.744       1.159
# ma.L1          0.8065      0.708      1.139      0.255      -0.581       2.194
# sigma2         1.8979      1.202      1.579      0.114      -0.457       4.253
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.77   Jarque-Bera (JB):                 0.82
# Prob(Q):                              0.38   Prob(JB):                         0.66
# Heteroskedasticity (H):               1.81   Skew:                             0.20
# Prob(H) (two-sided):                  0.58   Kurtosis:                         1.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 云南 (25/36) ---
# 为 '云南' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.455
# Date:                Wed, 26 Mar 2025   AIC                             40.910
# Time:                        13:00:31   BIC                             41.516
# Sample:                    12-31-2010   HQIC                            40.247
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7520      0.617      1.218      0.223      -0.458       1.962
# sigma2         2.3471      1.246      1.884      0.060      -0.095       4.789
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 1.51
# Prob(Q):                              0.72   Prob(JB):                         0.47
# Heteroskedasticity (H):               0.25   Skew:                             0.94
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 西藏 (26/36) ---
# 为 '西藏' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -25.498
# Date:                Wed, 26 Mar 2025   AIC                             52.996
# Time:                        13:00:32   BIC                             53.299
# Sample:                    12-31-2010   HQIC                            52.664
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         9.5997      5.256      1.826      0.068      -0.702      19.902
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                 0.21
# Prob(Q):                              0.20   Prob(JB):                         0.90
# Heteroskedasticity (H):               3.05   Skew:                            -0.08
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 陕西 (27/36) ---
# 为 '陕西' 找到的最佳 ARIMA 模型阶数: (1, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                 -25.998
# Date:                Wed, 26 Mar 2025   AIC                             55.995
# Time:                        13:00:32   BIC                             56.791
# Sample:                    12-31-2010   HQIC                            55.494
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8771      0.139      6.321      0.000       0.605       1.149
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3119      0.451      2.907      0.004       0.427       2.196
# ar.L2         -0.5021      0.385     -1.304      0.192      -1.257       0.253
# sigma2         2.3163      1.669      1.388      0.165      -0.955       5.588
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.14   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.81   Skew:                            -0.15
# Prob(H) (two-sided):                  0.84   Kurtosis:                         1.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 大连市 (32/36) ---
# 为 '大连市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -34.462
# Date:                Wed, 26 Mar 2025   AIC                             76.925
# Time:                        13:00:32   BIC                             78.864
# Sample:                    12-31-2010   HQIC                            76.207
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9988      0.024     41.692      0.000       0.952       1.046
# ma.L1          0.5881      0.642      0.916      0.359      -0.670       1.846
# ma.L2          0.5414      0.554      0.978      0.328      -0.544       1.627
# sigma2         9.1032      7.754      1.174      0.240      -6.094      24.300
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.54
# Prob(Q):                              0.84   Prob(JB):                         0.76
# Heteroskedasticity (H):               2.79   Skew:                            -0.16
# Prob(H) (two-sided):                  0.34   Kurtosis:                         2.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 宁波市 (33/36) ---
# 为 '宁波市' 找到的最佳 ARIMA 模型阶数: (1, 0, 2)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                 -33.333
# Date:                Wed, 26 Mar 2025   AIC                             76.665
# Time:                        13:00:32   BIC                             79.090
# Sample:                    12-31-2010   HQIC                            75.768
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     26.4557     96.668      0.274      0.784    -163.011     215.922
# ar.L1          0.8210      0.666      1.232      0.218      -0.485       2.127
# ma.L1          0.8449      1.355      0.624      0.533      -1.811       3.501
# ma.L2          0.5714      0.874      0.654      0.513      -1.142       2.285
# sigma2        11.1114      5.137      2.163      0.031       1.042      21.180
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.96   Prob(JB):                         0.71
# Heteroskedasticity (H):               2.21   Skew:                             0.57
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 厦门市 (34/36) ---
# 为 '厦门市' 找到的最佳 ARIMA 模型阶数: (1, 0, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -58.960
# Date:                Wed, 26 Mar 2025   AIC                            123.919
# Time:                        13:00:33   BIC                            125.374
# Sample:                    12-31-2010   HQIC                           123.380
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     27.9320    103.856      0.269      0.788    -175.621     231.485
# ar.L1          0.8531      0.598      1.427      0.154      -0.319       2.025
# sigma2       972.8598    843.183      1.154      0.249    -679.748    2625.468
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 8.70
# Prob(Q):                              0.86   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.01   Skew:                             1.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 青岛市 (35/36) ---
# 为 '青岛市' 找到的最佳 ARIMA 模型阶数: (0, 2, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                 -18.859
# Date:                Wed, 26 Mar 2025   AIC                             41.719
# Time:                        13:00:33   BIC                             42.324
# Sample:                    12-31-2010   HQIC                            41.055
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9010      0.505      1.785      0.074      -0.088       1.890
# sigma2         2.5447      2.034      1.251      0.211      -1.442       6.532
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.79
# Prob(Q):                              0.99   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.41   Skew:                            -0.03
# Prob(H) (two-sided):                  0.48   Kurtosis:                         1.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ------------------------------------------------------------
#
#
# --- 正在处理: 深圳市 (36/36) ---
# 为 '深圳市' 找到的最佳 ARIMA 模型阶数: (3, 1, 0)
# 模型详细参数:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   12
# Model:               SARIMAX(3, 1, 0)   Log Likelihood                 -41.004
# Date:                Wed, 26 Mar 2025   AIC                             92.008
# Time:                        13:00:33   BIC                             93.998
# Sample:                    12-31-2010   HQIC                            90.754
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -26.3866     10.419     -2.533      0.011     -46.808      -5.965
# ar.L1          0.3123      0.551      0.567      0.571      -0.767       1.392
# ar.L2         -0.2314      0.662     -0.349      0.727      -1.529       1.067
# ar.L3         -0.6714      0.579     -1.159      0.246      -1.807       0.464
# sigma2        69.8144     69.285      1.008      0.314     -65.982     205.611
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 0.33
# Prob(Q):                              0.63   Prob(JB):                         0.85
# Heteroskedasticity (H):               1.09   Skew:                             0.36
# Prob(H) (two-sided):                  0.94   Kurtosis:                         2.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# 2030    3.56%  135.26%  138.62%  106.29%  92.72%   78.22%  108.17%  55.67%  60.96%  138.16%  116.34%  41.73%   98.18%   67.05%   223.7%  200.33%   93.84%   117.0%  198.38%  145.42%  132.45%   61.04%  127.11%  220.59%  175.77%  163.67%  137.77%  95.94%  123.61%  109.98%  117.19%  132.18%  151.29%  199.79%   250.1%  278.31%
# 2031   -5.61%  135.64%  141.13%  107.56%  92.92%   74.94%  109.38%  51.88%  57.19%  139.76%  118.19%  33.44%   98.52%    61.8%  242.25%  205.46%   97.27%  117.39%  211.65%  148.69%  135.09%   53.64%  127.47%  228.36%  187.35%  170.15%  139.19%   96.6%   127.1%  110.67%  117.08%  132.02%  150.66%  198.38%  267.02%  246.83%
# 2032  -14.78%  136.02%  143.64%  108.83%  93.12%   71.66%  110.59%  48.09%  53.42%  141.36%  120.04%   25.0%    99.0%   56.55%  262.29%  210.59%  100.83%  117.78%  226.28%  151.96%  137.73%   46.24%  127.83%  235.74%  199.68%  176.63%  140.43%  97.26%  130.59%  111.36%  117.03%  131.85%  150.14%  197.18%  284.84%   211.1%
# 2033  -23.95%   136.4%  146.15%   110.1%  93.32%   68.38%   111.8%   44.3%  49.65%  142.96%  121.89%  16.45%    99.5%    51.3%  283.82%  215.72%  103.83%  118.17%  242.13%  155.23%  140.37%   38.84%  128.19%  242.77%  212.77%  183.11%  141.53%  97.92%  134.08%  112.05%  117.01%  131.69%  149.71%  196.15%  303.56%  188.93%
# 2034  -33.12%  136.78%  148.66%  111.37%  93.52%    65.1%  113.01%  40.51%  45.88%  144.56%  123.74%    7.8%   99.93%   46.05%  306.84%  220.85%  105.76%  118.56%  258.93%   158.5%  143.01%   31.44%  128.55%  249.46%   226.6%  189.59%  142.48%  98.58%  137.57%  112.74%  117.01%  131.53%  149.36%  195.28%  323.18%  185.01%
# 2035  -42.29%  137.16%  151.17%  112.64%  93.72%   61.82%  114.22%  36.72%  42.11%  146.16%  125.59%  -0.92%  100.27%    40.8%  331.35%  225.98%  106.39%  118.95%  276.47%  161.77%  145.65%   24.04%  128.91%  255.82%  241.19%  196.07%  143.32%  99.24%  141.06%  113.43%  117.03%  131.37%  149.07%  194.53%  343.71%  186.53%
#
# 预测结果已成功导出到文件: /Users/annfengdeye/Desktop/3.26下午2点/arima_forecast_2022_2035.csv

# %%
import pandas as pd
import numpy as np
import pmdarima as pm
import warnings
import matplotlib.pyplot as plt # 可选，用于绘图
import os
import sys # <--- 新增导入
import contextlib # <--- 新增导入

warnings.filterwarnings("ignore") # 忽略 ARIMA 拟合中可能出现的警告

# --- 新增：定义标准输出重定向的上下文管理器 ---
@contextlib.contextmanager
def redirect_stdout_to_file(filename, mode='w', encoding='utf-8'):
    """一个临时重定向 sys.stdout 到文件的上下文管理器。"""
    original_stdout = sys.stdout
    try:
        with open(filename, mode, encoding=encoding) as f:
            sys.stdout = f
            yield f # 可以选择性地 yield 文件对象，虽然这里没用到
    finally:
        sys.stdout = original_stdout # 保证无论如何都恢复 stdout
# --- 结束新增部分 ---

# 1. 准备数据 (保持不变)
data = {
    '年份': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2
'四川': [93.14, 97.87, 108.15, 103.63, 108.72, 110.33, 108.95, 106.4, 105.63, 102.65, 97.95, 93.17],
'贵州': [58.44, 67.43, 82.82, 74.54, 91.0, 101.92, 108.53, 109.0, 107.27, 107.13, 107.85, 105.53],
'云南': [59.96, 63.48, 70.71, 67.51, 73.29, 74.6, 79.43, 81.12, 83.86, 91.63, 95.23, 97.31],
'西藏': [28.44, 43.03, 57.81, 52.56, 62.49, 67.38, 72.41, 82.02, 92.27, 95.93, 97.43, 96.69],
'陕西': [90.87, 103.25, 117.3, 113.79, 125.79, 127.88, 127.45, 122.74, 118.83, 117.06, 110.27, 120.78],
'甘肃': [43.64, 47.83, 62.2, 56.65, 74.46, 96.29, 100.26, 101.62, 100.31, 102.8, 105.6, 107.44],
'青海': [53.5, 61.94, 70.92, 67.53, 74.73, 81.45, 84.54, 86.52, 85.28, 89.32, 89.83, 87.59],
'宁夏': [53.5, 58.52, 66.81, 63.08, 72.88, 78.71, 88.22, 92.48, 93.65, 94.41, 93.85, 89.92],
'新疆': [63.46, 66.4, 71.58, 69.46, 79.29, 89.55, 136.9, 142.45, 136.85, 118.59, 103.63, 92.53],
'大连市': [109.4, 109.35, 109.23, 108.73, 108.15, 102.72, 99.2, 101.14, 97.27, 96.98, 91.14, 99.85],
'宁波市': [192.29, 197.39, 198.22, 196.96, 232.02, 279.7, 267.52, 217.48, 186.66, 183.85, 179.88, 179.05],
'厦门市': [151.89, 162.83, 172.58, 183.14, 182.79, 177.07, 170.93, 167.4, 155.47, 153.11, 146.2, 147.66],
'青岛市': [89.96, 102.93, 112.71, 112.65, 108.83, 108.34, 103.45, 106.53, 104.86, 103.89, 113.05, 121.38],
'深圳市': [285.58, 277.18, 284.98, 316.08, 303.68, 286.36, 263.83, 260.86, 246.73, 217.35, 191.39, 184.1]
}
df = pd.DataFrame(data)
df['年份'] = pd.to_datetime(df['年份'], format='%Y')
df.set_index('年份', inplace=True)
df.index = df.index.to_period('A')

# 2. 定义预测参数 (保持不变)
locations = list(data.keys())[1:]
forecast_horizon = 2035 - 2021

# --- 定义输出文件名 ---
output_log_filename = 'arima_processing_log.txt'
output_csv_filename = 'arima_forecast_2022_2035.csv'

# --- 在重定向前打印一条消息到控制台 ---
print(f"--- 开始处理，所有详细文本输出将写入文件: {output_log_filename} ---")
print(f"--- 最终预测表将导出到 CSV 文件: {output_csv_filename} ---")

# --- 使用上下文管理器重定向输出 ---
try:
    with redirect_stdout_to_file(output_log_filename, encoding='utf-8'):

        # 3. 循环为每个地区/城市进行 ARIMA 预测 (现在 print 会写入文件)
        forecast_results = {}
        fitted_models = {}

        print(f"共 {len(locations)} 个地区/城市需要处理。") # <-- 写入文件
        print("开始为每个地区/城市拟合 ARIMA 模型并预测...\n") # <-- 写入文件

        for i, loc in enumerate(locations):
            print(f"--- 正在处理: {loc} ({i+1}/{len(locations)}) ---") # <-- 写入文件
            series = df[loc]
            try:
                auto_model = pm.auto_arima(series, start_p=0, start_q=0, max_p=3, max_q=3, m=1, d=None, test='adf',
                                           seasonal=False, stepwise=True, suppress_warnings=True, error_action='ignore', trace=False)
                if auto_model is None or not hasattr(auto_model, 'order'):
                     raise ValueError("auto_arima未能找到合适的模型。")
                print(f"为 '{loc}' 找到的最佳 ARIMA 模型阶数: {auto_model.order}") # <-- 写入文件
                print("模型详细参数:") # <-- 写入文件
                print(auto_model.summary()) # <-- 写入文件 (summary 的输出也会被捕获)
                print("-" * 60) # <-- 写入文件
                fitted_models[loc] = auto_model
                forecast, conf_int = auto_model.predict(n_periods=forecast_horizon, return_conf_int=True)
                forecast_results[loc] = forecast
            except Exception as e:
                print(f"!!! 无法为 '{loc}' 拟合或预测 ARIMA 模型: {e}") # <-- 写入文件
                print("   可能是因为数据序列过短、模式不明显、数值过大/波动剧烈或auto_arima搜索失败。") # <-- 写入文件
                forecast_results[loc] = [np.nan] * forecast_horizon
                fitted_models[loc] = None
            finally:
                print("\n") # <-- 写入文件


        # 4. 整理并展示预测结果 (现在 print 会写入文件)
        forecast_index = pd.period_range(start=str(df.index[-1].year + 1), periods=forecast_horizon, freq='A')
        forecast_df = pd.DataFrame(forecast_results, index=forecast_index)
        forecast_df_formatted = forecast_df.round(2).astype(str) + '%'
        forecast_df_formatted = forecast_df_formatted.replace('nan%', 'N/A')

        print("\n\n--- ARIMA 模型预测结果 (2022-2035) ---") # <-- 写入文件

        # 为了确保 DataFrame 完整打印到文件，使用 to_string()
        pd.set_option('display.max_rows', None)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 2000) # 设置足够宽的宽度
        print(forecast_df_formatted.to_string()) # <-- 将完整表格写入文件
        pd.reset_option('display.max_rows')
        pd.reset_option('display.max_columns')
        pd.reset_option('display.width')

        # 导出到 CSV (打印的确认信息也会写入 TXT 文件)
        try:
            # 使用 utf-8-sig 编码确保 Excel 正确识别中文和特殊字符
            forecast_df_formatted.to_csv(output_csv_filename, encoding='utf-8-sig')
            print(f"\n预测结果已成功导出到 CSV 文件: {os.path.abspath(output_csv_filename)}") # <-- 写入文件
        except Exception as e:
            print(f"\n!!! 导出 CSV 文件时出错: {e}") # <-- 写入文件

        # 打印绘图准备信息 (也会写入 TXT 文件)
        plot_results = True # 设置为 False 则不绘图
        if plot_results:
            print("\n--- 正在准备绘制结果图表 (图表将单独显示)... ---") # <-- 写入文件

    # --- 重定向结束，后续 print 会回到控制台 ---
    print(f"--- 处理完成，详细文本输出已写入: {os.path.abspath(output_log_filename)} ---")

except Exception as global_error:
    # 捕获在重定向期间可能发生的其他未预料错误
    print(f"!!! 脚本执行过程中发生严重错误: {global_error} !!!")
    # 尝试将错误信息追加到日志文件
    try:
        with open(output_log_filename, 'a', encoding='utf-8') as f_err:
             f_err.write(f"\n\n!!! 脚本执行过程中发生严重错误: {global_error} !!!\n")
    except:
        pass # 忽略记录错误时发生的错误
# Out:
# --- 开始处理，所有详细文本输出将写入文件: arima_processing_log.txt ---
# --- 最终预测表将导出到 CSV 文件: arima_forecast_2022_2035.csv ---
# --- 处理完成，详细文本输出已写入: /Users/annfengdeye/Desktop/3.26下午2点/arima_processing_log.txt ---
